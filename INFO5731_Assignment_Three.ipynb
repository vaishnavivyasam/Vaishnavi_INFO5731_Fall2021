# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavivyasam/Vaishnavi_INFO5731_Fall2021/blob/main/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment. (Use 500 records amount all the data you collected).

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as the 500 reviews (abstracts, or tweets).

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c524fd55-e245-4d24-ba25-9f56c9058c25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c524fd55-e245-4d24-ba25-9f56c9058c25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving citeseerX.csv to citeseerX.csv

# %%
import pandas as pd
df = pd.read_csv("citeseerX.csv")
df.head()
# Out:
#    Unnamed: 0  ...                                           Abstract
# 0           0  ...  "...  ABSTRACT Using dealer's quotes and trans...
# 1           1  ...  "... ABSTRACT: “Smart ” sensors with embedded ...
# 2           2  ...  "... of excellence in research and education t...
# 3           3  ...  "...  Abstract Many financial markets are char...
# 4           4  ...  "... Abstract—The design and development of we...
#
# [5 rows x 3 columns]

# %%
# !pip install nltk
import nltk
#Remove noise
df['Abstract'] = df['Abstract'].str.replace('[^\w\s]','')
#df['tweet_text'].head()

#Removing stopwords
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Abstract'] = df['Abstract'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['Abstract']

#Removing numbers
df['Abstract'] = df['Abstract'].apply(lambda x: " ".join(x for x in x.split() if not x.isdigit()))
df['Abstract']

#converting to lowercase
df['Abstract'] = df['Abstract'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['Abstract']

#stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['Abstract'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

#lemmatization
# !pip install -U textblob
from textblob import Word
import nltk
nltk.download('wordnet')

df['Abstract'] = df['Abstract'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df['Abstract'].head()
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.15.0)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0    abstract using dealer quote transaction price ...
# 1    abstract smart sensor embedded microprocessor ...
# 2    excellence research education contributed grea...
# 3    abstract many financial market characterized s...
# 4    abstractthe design development wearable biosen...
# Name: Abstract, dtype: object

# %%
df.to_csv('clean_text.csv')

# %%
import nltk
from nltk.util import ngrams

# %%
clean_data = open('clean_text.csv', "r")
unigrams = ngrams(clean_data.read().split(), 1)
unigra_freq_dist=nltk.FreqDist(unigrams)

# %%
clean_data = open('clean_text.csv', "r")
bigrams = ngrams(clean_data.read().split(), 2)
bigra_freq_dist=nltk.FreqDist(bigrams)

# %%
#1.1 Count the frequency of all the N-grams (N=3)
clean_data = open('clean_text.csv', "r")
trigrams = ngrams(clean_data.read().split(), 3)
trigra_freq_dist=nltk.FreqDist(trigrams)
trigra_freq_dist
# Out:
# FreqDist({(',Unnamed:', '0,Title,Abstract', '0,0,The'): 1,
#           ('0,Title,Abstract', '0,0,The', 'Determinants'): 1,
#           ('0,0,The', 'Determinants', 'of'): 1,
#           ('Determinants', 'of', 'Credit'): 7,
#           ('of', 'Credit', 'Spread'): 7,
#           ('Credit', 'Spread', 'Changes.,abstract'): 7,
#           ('Spread', 'Changes.,abstract', 'using'): 7,
#           ('Changes.,abstract', 'using', 'dealer'): 7,
#           ('using', 'dealer', 'quote'): 7,
#           ('dealer', 'quote', 'transaction'): 7,
#           ('quote', 'transaction', 'price'): 7,
#           ('transaction', 'price', 'straight'): 7,
#           ('price', 'straight', 'industrial'): 7,
#           ('straight', 'industrial', 'bond'): 7,
#           ('industrial', 'bond', 'investigate'): 7,
#           ('bond', 'investigate', 'determinant'): 7,
#           ('investigate', 'determinant', 'credit'): 7,
#           ('determinant', 'credit', 'spread'): 7,
#           ('credit', 'spread', 'change'): 14,
#           ('spread', 'change', 'variable'): 7,
#           ('change', 'variable', 'theory'): 7,
#           ('variable', 'theory', 'determine'): 7,
#           ('theory', 'determine', 'credit'): 7,
#           ('determine', 'credit', 'spread'): 7,
#           ('spread', 'change', 'rather'): 7,
#           ('change', 'rather', 'limited'): 7,
#           ('rather', 'limited', 'explanatory'): 7,
#           ('limited', 'explanatory', 'power'): 7,
#           ('explanatory', 'power', 'residual'): 7,
#           ('power', 'residual', 'regression'): 7,
#           ('residual', 'regression', '1,1,Smart'): 1,
#           ('regression', '1,1,Smart', 'Sensing'): 1,
#           ('1,1,Smart', 'Sensing', 'Technology:'): 1,
#           ('Sensing', 'Technology:', 'Opportunities'): 100,
#           ('Technology:', 'Opportunities', 'and'): 100,
#           ('Opportunities', 'and', 'Challenges,abstract'): 100,
#           ('and', 'Challenges,abstract', 'smart'): 100,
#           ('Challenges,abstract', 'smart', 'sensor'): 100,
#           ('smart', 'sensor', 'embedded'): 100,
#           ('sensor', 'embedded', 'microprocessor'): 200,
#           ('embedded', 'microprocessor', 'wireless'): 200,
#           ('microprocessor', 'wireless', 'communication'): 200,
#           ('wireless', 'communication', 'link'): 200,
#           ('communication', 'link', 'potential'): 200,
#           ('link', 'potential', 'change'): 100,
#           ('potential', 'change', 'fundamentally'): 100,
#           ('change', 'fundamentally', 'way'): 100,
#           ('fundamentally', 'way', 'civil'): 100,
#           ('way', 'civil', 'infrastructure'): 200,
#           ('civil', 'infrastructure', 'system'): 200,
#           ('infrastructure', 'system', 'monitored'): 200,
#           ('system', 'monitored', 'controlled'): 200,
#           ('monitored', 'controlled', 'maintained'): 200,
#           ('controlled', 'maintained', 'indeed'): 200,
#           ('maintained', 'indeed', 'national'): 200,
#           ('indeed', 'national', 'research'): 200,
#           ('national', 'research', 'council'): 200,
#           ('research', 'council', 'report'): 200,
#           ('council', 'report', 'noted'): 200,
#           ('report', 'noted', 'use'): 200,
#           ('noted', 'use', 'networked'): 200,
#           ('use', 'networked', 'system'): 200,
#           ('networked', 'system', '2,2,Structural'): 1,
#           ('system', '2,2,Structural', 'health'): 1,
#           ('2,2,Structural', 'health', 'monitoring'): 1,
#           ('health', 'monitoring', 'using'): 100,
#           ('monitoring', 'using', 'smart'): 100,
#           ('using', 'smart', 'sensors,excellence'): 100,
#           ('smart', 'sensors,excellence', 'research'): 100,
#           ('sensors,excellence', 'research', 'education'): 100,
#           ('research', 'education', 'contributed'): 100,
#           ('education', 'contributed', 'greatly'): 100,
#           ('contributed', 'greatly', 'stateoftheart'): 100,
#           ('greatly', 'stateoftheart', 'civil'): 100,
#           ('stateoftheart', 'civil', 'engineering'): 100,
#           ('civil', 'engineering', 'completed'): 100,
#           ('engineering', 'completed', 'extended'): 100,
#           ('completed', 'extended', 'structural'): 100,
#           ('extended', 'structural', 'testing'): 100,
#           ('structural', 'testing', 'area'): 100,
#           ('testing', 'area', 'laboratory'): 100,
#           ('area', 'laboratory', 'versatile'): 100,
#           ('laboratory', 'versatile', 'strongfloorwall'): 100,
#           ('versatile', 'strongfloorwall', 'threestory'): 100,
#           ('strongfloorwall', 'threestory', 'clear'): 100,
#           ('threestory', 'clear', 'height'): 100,
#           ('clear', 'height', 'used'): 100,
#           ('height', 'used', 'carry'): 100,
#           ('used', 'carry', 'wi'): 100,
#           ('carry', 'wi', '3,3,"Whom'): 1,
#           ('wi', '3,3,"Whom', 'You'): 1,
#           ('3,3,"Whom', 'You', 'Know'): 1,
#           ('You', 'Know', 'Matters:'): 49,
#           ('Know', 'Matters:', 'Venture'): 49,
#           ('Matters:', 'Venture', 'Capital'): 49,
#           ('Venture', 'Capital', 'Networks'): 49,
#           ('Capital', 'Networks', 'and'): 49,
#           ('Networks', 'and', 'Investment'): 49,
#           ('and', 'Investment', 'Performance,",abstract'): 49,
#           ('Investment', 'Performance,",abstract', 'many'): 49,
#           ('Performance,",abstract', 'many', 'financial'): 49,
#           ('many', 'financial', 'market'): 49,
#           ('financial', 'market', 'characterized'): 49,
#           ('market', 'characterized', 'strong'): 49,
#           ('characterized', 'strong', 'relationship'): 49,
#           ('strong', 'relationship', 'network'): 49,
#           ('relationship', 'network', 'rather'): 49,
#           ('network', 'rather', 'armslength'): 49,
#           ('rather', 'armslength', 'spotmarket'): 49,
#           ('armslength', 'spotmarket', 'transaction'): 49,
#           ('spotmarket', 'transaction', 'examine'): 49,
#           ('transaction', 'examine', 'performance'): 49,
#           ('examine', 'performance', 'consequence'): 49,
#           ('performance', 'consequence', 'organizational'): 49,
#           ('consequence', 'organizational', 'choice'): 49,
#           ('organizational', 'choice', 'context'): 49,
#           ('choice', 'context', 'relationship'): 49,
#           ('context', 'relationship', 'established'): 49,
#           ('relationship', 'established', 'vcs'): 49,
#           ('established', 'vcs', 'syndicate'): 49,
#           ('vcs', 'syndicate', 'portfolio'): 49,
#           ('syndicate', 'portfolio', 'company'): 49,
#           ('portfolio', 'company', 'inv'): 49,
#           ('company', 'inv', '4,4,A'): 1,
#           ('inv', '4,4,A', 'Survey'): 1,
#           ('4,4,A', 'Survey', 'on'): 1,
#           ('Survey', 'on', 'Wearable'): 100,
#           ('on', 'Wearable', 'Sensor-Based'): 100,
#           ('Wearable', 'Sensor-Based', 'Systems'): 100,
#           ('Sensor-Based', 'Systems', 'for'): 100,
#           ('Systems', 'for', 'Health'): 100,
#           ('for', 'Health', 'Monitoring'): 100,
#           ('Health', 'Monitoring', 'and'): 100,
#           ('Monitoring', 'and', 'Prognosis,abstractthe'): 100,
#           ('and', 'Prognosis,abstractthe', 'design'): 100,
#           ('Prognosis,abstractthe', 'design', 'development'): 100,
#           ('design', 'development', 'wearable'): 100,
#           ('development', 'wearable', 'biosensor'): 100,
#           ('wearable', 'biosensor', 'system'): 100,
#           ('biosensor', 'system', 'health'): 100,
#           ('system', 'health', 'monitoring'): 100,
#           ('health', 'monitoring', 'garnered'): 100,
#           ('monitoring', 'garnered', 'lot'): 100,
#           ('garnered', 'lot', 'attention'): 100,
#           ('lot', 'attention', 'scientific'): 100,
#           ('attention', 'scientific', 'community'): 100,
#           ('scientific', 'community', 'industry'): 100,
#           ('community', 'industry', 'last'): 100,
#           ('industry', 'last', 'year'): 100,
#           ('last', 'year', 'mainly'): 100,
#           ('year', 'mainly', 'motivated'): 100,
#           ('mainly', 'motivated', 'increasing'): 100,
#           ('motivated', 'increasing', 'healthcare'): 100,
#           ('increasing', 'healthcare', 'cost'): 100,
#           ('healthcare', 'cost', 'propelled'): 100,
#           ('cost', 'propelled', 'recent'): 100,
#           ('propelled', 'recent', 'technological'): 100,
#           ('recent', 'technological', 'advance'): 100,
#           ('technological', 'advance', 'miniature'): 100,
#           ('advance', 'miniature', 'biose'): 100,
#           ('miniature', 'biose', '5,5,The'): 1,
#           ('biose', '5,5,The', 'SmartPhone'): 1,
#           ('5,5,The', 'SmartPhone', 'as'): 1,
#           ('SmartPhone', 'as', 'a'): 100,
#           ('as', 'a', 'platform'): 100,
#           ('a', 'platform', 'for'): 100,
#           ('platform', 'for', 'wearable'): 100,
#           ('for', 'wearable', 'cameras'): 100,
#           ('wearable', 'cameras', 'in'): 100,
#           ('cameras', 'in', 'health'): 100,
#           ('in', 'health', 'research,background'): 100,
#           ('health', 'research,background', 'sensecam'): 100,
#           ('research,background', 'sensecam', 'small'): 100,
#           ('sensecam', 'small', 'camera'): 100,
#           ('small', 'camera', 'worn'): 100,
#           ('camera', 'worn', 'chest'): 100,
#           ('worn', 'chest', 'via'): 100,
#           ('chest', 'via', 'lanyard'): 100,
#           ('via', 'lanyard', 'increasingly'): 100,
#           ('lanyard', 'increasingly', 'deployed'): 100,
#           ('increasingly', 'deployed', 'health'): 100,
#           ('deployed', 'health', 'research'): 100,
#           ('health', 'research', 'however'): 100,
#           ('research', 'however', 'sensecam'): 100,
#           ('however', 'sensecam', 'yet'): 100,
#           ('sensecam', 'yet', 'widespread'): 100,
#           ('yet', 'widespread', 'use'): 100,
#           ('widespread', 'use', 'due'): 100,
#           ('use', 'due', 'variety'): 100,
#           ('due', 'variety', 'factor'): 100,
#           ('variety', 'factor', 'proposed'): 100,
#           ('factor', 'proposed', 'ubiquitous'): 100,
#           ('proposed', 'ubiquitous', 'smartphone'): 100,
#           ('ubiquitous', 'smartphone', 'provide'): 100,
#           ('smartphone', 'provide', 'accessible'): 100,
#           ('provide', 'accessible', 'alternati'): 100,
#           ('accessible', 'alternati', '6,6,SMART'): 1,
#           ('alternati', '6,6,SMART', 'SENSING'): 1,
#           ('6,6,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('SENSING', 'TECHNOLOGY', 'FOR'): 100,
#           ('TECHNOLOGY', 'FOR', 'STRUCTURAL'): 100,
#           ('FOR', 'STRUCTURAL', 'HEALTH'): 195,
#           ('STRUCTURAL', 'HEALTH', 'MONITORING,smart'): 100,
#           ('HEALTH', 'MONITORING,smart', 'sensor'): 100,
#           ('MONITORING,smart', 'sensor', 'embedded'): 100,
#           ('link', 'potential', 'fundamentally'): 100,
#           ('potential', 'fundamentally', 'change'): 100,
#           ('fundamentally', 'change', 'way'): 100,
#           ('change', 'way', 'civil'): 100,
#           ('networked', 'system', 'em'): 100,
#           ('system',
#            'em',
#            '7,7,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '7,7,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('7,7,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('smart', 'home', 'nowadays'): 99,
#           ('home', 'nowadays', 'explored'): 99,
#           ('nowadays', 'explored', 'research'): 99,
#           ('explored', 'research', 'area'): 99,
#           ('research', 'area', 'due'): 99,
#           ('area', 'due', 'need'): 99,
#           ('due', 'need', 'home'): 99,
#           ('need', 'home', 'automation'): 99,
#           ('home', 'automation', 'telemedicine'): 99,
#           ('automation', 'telemedicine', 'support'): 99,
#           ('telemedicine', 'support', 'people'): 99,
#           ('support', 'people', 'loss'): 99,
#           ('people', 'loss', 'autonomy'): 99,
#           ('loss', 'autonomy', 'also'): 99,
#           ('autonomy', 'also', 'due'): 99,
#           ('also', 'due', 'evolution'): 99,
#           ('due', 'evolution', 'technology'): 99,
#           ('evolution', 'technology', 'resulted'): 99,
#           ('technology', 'resulted', 'cheap'): 99,
#           ('resulted', 'cheap', 'efficient'): 99,
#           ('cheap', 'efficient', 'sensor'): 99,
#           ('efficient', 'sensor', 'however'): 99,
#           ('sensor', 'however', 'many'): 99,
#           ('however', 'many', 'study'): 99,
#           ('many', 'study', 'include'): 99,
#           ('study', 'include', 'test'): 99,
#           ('include', 'test', '8,8,SMART'): 1,
#           ('test', '8,8,SMART', 'TECHNOLOGIES'): 1,
#           ('8,8,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('TECHNOLOGIES', 'FOR', 'STRUCTURAL'): 95,
#           ('STRUCTURAL', 'HEALTH', 'MONITORING'): 95,
#           ('HEALTH', 'MONITORING', 'OF'): 95,
#           ('MONITORING', 'OF', 'AEROSPACE'): 95,
#           ('OF', 'AEROSPACE', 'STRUCTURES,paper'): 95,
#           ('AEROSPACE', 'STRUCTURES,paper', 'present'): 95,
#           ('STRUCTURES,paper', 'present', 'recent'): 95,
#           ('present', 'recent', 'advance'): 95,
#           ('recent', 'advance', 'structural'): 95,
#           ('advance', 'structural', 'health'): 95,
#           ('structural', 'health', 'monitoring'): 96,
#           ('health', 'monitoring', 'shm'): 96,
#           ('monitoring', 'shm', 'project'): 95,
#           ('shm', 'project', 'within'): 95,
#           ('project', 'within', 'consortium'): 95,
#           ('within', 'consortium', 'research'): 95,
#           ('consortium', 'research', 'innovation'): 95,
#           ('research', 'innovation', 'aerospace'): 95,
#           ('innovation', 'aerospace', 'québec'): 95,
#           ('aerospace', 'québec', 'criaq'): 95,
#           ('québec', 'criaq', 'project'): 95,
#           ('criaq', 'project', 'aim'): 95,
#           ('project', 'aim', 'developing'): 95,
#           ('aim', 'developing', 'technology'): 95,
#           ('developing', 'technology', 'shm'): 95,
#           ('technology', 'shm', 'system'): 95,
#           ('shm', 'system', 'potentially'): 95,
#           ('system', 'potentially', 'reducing'): 95,
#           ('potentially', 'reducing', 'high'): 95,
#           ('reducing', 'high', 'cost'): 95,
#           ('high', 'cost', 'associated'): 95,
#           ('cost', 'associated', 'periodic'): 95,
#           ('associated', 'periodic', 'presc'): 95,
#           ('periodic', 'presc', '9,9,Occasional'): 1,
#           ('presc', '9,9,Occasional', 'Paper'): 1,
#           ('9,9,Occasional', 'Paper', '11,organic'): 1,
#           ('Paper', '11,organic', 'resourceconserving'): 1,
#           ('11,organic', 'resourceconserving', 'agriculture'): 1,
#           ('resourceconserving', 'agriculture', 'improve'): 1,
#           ('agriculture', 'improve', 'livelihood'): 1,
#           ('improve', 'livelihood', 'metaanalysis'): 1,
#           ('livelihood', 'metaanalysis', 'conceptual'): 1,
#           ('metaanalysis', 'conceptual', 'framework'): 1,
#           ('conceptual', 'framework', 'sitespecific'): 1,
#           ('framework', 'sitespecific', 'evaluation'): 1,
#           ('sitespecific', 'evaluation', 'mica'): 1,
#           ('evaluation', 'mica', 'bennett'): 1,
#           ('mica', 'bennett', 'steven'): 1,
#           ('bennett', 'steven', 'franzelthe'): 1,
#           ('steven', 'franzelthe', 'world'): 1,
#           ('franzelthe', 'world', 'agroforestry'): 1,
#           ('world', 'agroforestry', 'centre'): 1,
#           ('agroforestry', 'centre', 'autonomous'): 1,
#           ('centre', 'autonomous', 'nonprofit'): 1,
#           ('autonomous', 'nonprofit', 'research'): 1,
#           ('nonprofit', 'research', 'organization'): 1,
#           ('research', 'organization', 'aim'): 1,
#           ('organization', 'aim', 'bring'): 1,
#           ('aim', 'bring', 'rural'): 1,
#           ('bring', 'rural', 'transformation'): 1,
#           ('rural', 'transformation', 'deve'): 1,
#           ('transformation', 'deve', '10,10,The'): 1,
#           ('deve', '10,10,The', 'Determinants'): 1,
#           ('10,10,The', 'Determinants', 'of'): 1,
#           ('residual', 'regression', '11,11,"Stress,'): 1,
#           ('regression', '11,11,"Stress,', 'coping'): 1,
#           ('11,11,"Stress,', 'coping', 'and'): 1,
#           ('coping', 'and', 'social'): 3,
#           ('and', 'social', 'support'): 3,
#           ('social', 'support', 'processes:'): 3,
#           ('support', 'processes:', 'Where'): 3,
#           ('processes:', 'Where', 'are'): 3,
#           ('Where', 'are', 'we?'): 3,
#           ('are', 'we?', 'What'): 3,
#           ('we?', 'What', 'next?",jstor'): 3,
#           ('What', 'next?",jstor', 'notforprofit'): 3,
#           ('next?",jstor', 'notforprofit', 'service'): 3,
#           ('notforprofit', 'service', 'help'): 3,
#           ('service', 'help', 'scholar'): 3,
#           ('help', 'scholar', 'researcher'): 3,
#           ('scholar', 'researcher', 'student'): 3,
#           ('researcher', 'student', 'discover'): 3,
#           ('student', 'discover', 'use'): 3,
#           ('discover', 'use', 'build'): 3,
#           ('use', 'build', 'upon'): 3,
#           ('build', 'upon', 'wide'): 3,
#           ('upon', 'wide', 'range'): 3,
#           ('wide', 'range', 'content'): 3,
#           ('range', 'content', 'trusted'): 3,
#           ('content', 'trusted', 'digital'): 3,
#           ('trusted', 'digital', 'archive'): 3,
#           ('digital', 'archive', 'use'): 3,
#           ('archive', 'use', 'information'): 3,
#           ('use', 'information', 'technology'): 3,
#           ('information', 'technology', 'tool'): 3,
#           ('technology', 'tool', 'increase'): 3,
#           ('tool', 'increase', 'productivity'): 3,
#           ('increase', 'productivity', 'facilitate'): 3,
#           ('productivity', 'facilitate', 'new'): 3,
#           ('facilitate', 'new', 'form'): 3,
#           ('new', 'form', 'scholarship'): 3,
#           ('form', 'scholarship', 'information'): 3,
#           ('scholarship', 'information', 'j'): 3,
#           ('information', 'j', '12,12,Smart'): 1,
#           ('j', '12,12,Smart', 'Sensing'): 1,
#           ('12,12,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '13,13,Structural'): 1,
#           ('system', '13,13,Structural', 'health'): 1,
#           ('13,13,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '14,14,"Whom'): 1,
#           ('wi', '14,14,"Whom', 'You'): 1,
#           ('14,14,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '15,15,Experimental'): 1,
#           ('inv', '15,15,Experimental', 'Evaluation'): 1,
#           ('15,15,Experimental', 'Evaluation', 'in'): 1,
#           ('Evaluation', 'in', 'Computer'): 7,
#           ('in', 'Computer', 'Science:'): 7,
#           ('Computer', 'Science:', 'A'): 7,
#           ('Science:', 'A', 'Quantitative'): 7,
#           ('A', 'Quantitative', 'Study,survey'): 7,
#           ('Quantitative', 'Study,survey', 'recent'): 7,
#           ('Study,survey', 'recent', 'research'): 7,
#           ('recent', 'research', 'article'): 7,
#           ('research', 'article', 'suggests'): 7,
#           ('article', 'suggests', 'computer'): 7,
#           ('suggests', 'computer', 'scientist'): 7,
#           ('computer', 'scientist', 'publish'): 7,
#           ('scientist', 'publish', 'relatively'): 7,
#           ('publish', 'relatively', 'paper'): 7,
#           ('relatively', 'paper', 'experimentally'): 7,
#           ('paper', 'experimentally', 'validated'): 7,
#           ('experimentally', 'validated', 'result'): 7,
#           ('validated', 'result', 'survey'): 7,
#           ('result', 'survey', 'includes'): 7,
#           ('survey', 'includes', 'complete'): 7,
#           ('includes', 'complete', 'volume'): 7,
#           ('complete', 'volume', 'several'): 7,
#           ('volume', 'several', 'refereed'): 7,
#           ('several', 'refereed', 'computer'): 7,
#           ('refereed', 'computer', 'science'): 7,
#           ('computer', 'science', 'journal'): 7,
#           ('science', 'journal', 'conference'): 7,
#           ('journal', 'conference', 'title'): 7,
#           ('conference', 'title', 'drawn'): 7,
#           ('title', 'drawn', 'random'): 7,
#           ('drawn', 'random', 'article'): 7,
#           ('random', 'article', 'published'): 7,
#           ('article', 'published', '16,16,A'): 1,
#           ('published', '16,16,A', 'Survey'): 1,
#           ('16,16,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '17,17,Compassionate'): 1,
#           ('biose', '17,17,Compassionate', 'mind'): 1,
#           ('17,17,Compassionate', 'mind', 'training'): 1,
#           ('mind', 'training', 'for'): 1,
#           ('training', 'for', 'people'): 1,
#           ('for', 'people', 'with'): 1,
#           ('people', 'with', 'high'): 1,
#           ('with', 'high', 'shame'): 1,
#           ('high', 'shame', 'and'): 1,
#           ('shame', 'and', 'self-criticism:'): 1,
#           ('and', 'self-criticism:', 'Overview'): 1,
#           ('self-criticism:', 'Overview', 'and'): 1,
#           ('Overview', 'and', 'pilot'): 1,
#           ('and', 'pilot', 'study'): 1,
#           ('pilot', 'study', 'of'): 1,
#           ('study', 'of', 'a'): 1,
#           ('of', 'a', 'group'): 1,
#           ('a', 'group', 'of'): 1,
#           ('group', 'of', 'therapy'): 1,
#           ('of', 'therapy', 'approach,compassionate'): 1,
#           ('therapy', 'approach,compassionate', 'mind'): 1,
#           ('approach,compassionate', 'mind', 'training'): 1,
#           ('mind', 'training', 'cmt'): 1,
#           ('training', 'cmt', 'developed'): 1,
#           ('cmt', 'developed', 'people'): 1,
#           ('developed', 'people', 'high'): 1,
#           ('people', 'high', 'shame'): 1,
#           ('high', 'shame', 'selfcriticism'): 1,
#           ('shame', 'selfcriticism', 'whose'): 1,
#           ('selfcriticism', 'whose', 'problem'): 1,
#           ('whose', 'problem', 'tend'): 1,
#           ('problem', 'tend', 'chronic'): 1,
#           ('tend', 'chronic', 'find'): 1,
#           ('chronic', 'find', 'selfwarmth'): 1,
#           ('find', 'selfwarmth', 'selfacceptance'): 1,
#           ('selfwarmth', 'selfacceptance', 'difficult'): 1,
#           ('selfacceptance', 'difficult', 'andor'): 1,
#           ('difficult', 'andor', 'frightening'): 1,
#           ('andor', 'frightening', 'paper'): 1,
#           ('frightening', 'paper', 'offer'): 1,
#           ('paper', 'offer', 'short'): 1,
#           ('offer', 'short', 'overview'): 1,
#           ('short', 'overview', 'role'): 1,
#           ('overview', 'role', 'shame'): 1,
#           ('role', 'shame', 'selfcriticism'): 1,
#           ('shame', 'selfcriticism', 'psychological'): 1,
#           ('selfcriticism', 'psychological', 'dif'): 1,
#           ('psychological', 'dif', '18,18,The'): 1,
#           ('dif', '18,18,The', 'SmartPhone'): 1,
#           ('18,18,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '19,19,SMART'): 1,
#           ('alternati', '19,19,SMART', 'SENSING'): 1,
#           ('19,19,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system', 'em', '20,20,Smart'): 1,
#           ('em', '20,20,Smart', 'Sensing'): 1,
#           ('20,20,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '21,21,Structural'): 1,
#           ('system', '21,21,Structural', 'health'): 1,
#           ('21,21,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '22,22,"Whom'): 1,
#           ('wi', '22,22,"Whom', 'You'): 1,
#           ('22,22,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '23,23,A'): 1,
#           ('inv', '23,23,A', 'Survey'): 1,
#           ('23,23,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '24,24,The'): 1,
#           ('biose', '24,24,The', 'SmartPhone'): 1,
#           ('24,24,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '25,25,SMART'): 1,
#           ('alternati', '25,25,SMART', 'SENSING'): 1,
#           ('25,25,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '26,26,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '26,26,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('26,26,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '27,27,SMART'): 1,
#           ('test', '27,27,SMART', 'TECHNOLOGIES'): 1,
#           ('27,27,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '28,28,ADVANCED'): 1,
#           ('presc', '28,28,ADVANCED', 'COMPOSITES'): 1,
#           ('28,28,ADVANCED', 'COMPOSITES', 'FOR'): 1,
#           ('COMPOSITES', 'FOR', 'SMART'): 87,
#           ('FOR', 'SMART', 'STRUCTURES,summary'): 87,
#           ('SMART', 'STRUCTURES,summary', 'many'): 87,
#           ('STRUCTURES,summary', 'many', 'advanced'): 87,
#           ('many', 'advanced', 'composite'): 87,
#           ('advanced', 'composite', 'material'): 87,
#           ('composite', 'material', 'proposed'): 87,
#           ('material', 'proposed', 'smart'): 87,
#           ('proposed', 'smart', 'structure'): 87,
#           ('smart', 'structure', 'beside'): 87,
#           ('structure', 'beside', 'aramid'): 87,
#           ('beside', 'aramid', 'glass'): 87,
#           ('aramid', 'glass', 'carbon'): 87,
#           ('glass', 'carbon', 'fibre'): 87,
#           ('carbon', 'fibre', 'reinforced'): 87,
#           ('fibre', 'reinforced', 'polymer'): 87,
#           ('reinforced', 'polymer', 'frp'): 87,
#           ('polymer', 'frp', 'used'): 87,
#           ('frp', 'used', 'replace'): 87,
#           ('used', 'replace', 'steel'): 87,
#           ('replace', 'steel', 'bar'): 87,
#           ('steel', 'bar', 'strand'): 87,
#           ('bar', 'strand', 'wire'): 87,
#           ('strand', 'wire', 'tendon'): 87,
#           ('wire', 'tendon', 'structure'): 87,
#           ('tendon', 'structure', 'frp'): 87,
#           ('structure', 'frp', 'panel'): 87,
#           ('frp', 'panel', 'membrane'): 87,
#           ('panel', 'membrane', 'textile'): 87,
#           ('membrane', 'textile', 'used'): 87,
#           ('textile', 'used', 'type'): 87,
#           ('used', 'type', 'st'): 87,
#           ('type', 'st', '29,29,Distributed'): 1,
#           ('st', '29,29,Distributed', 'Intelligence'): 1,
#           ('29,29,Distributed', 'Intelligence', 'for'): 1,
#           ('Intelligence', 'for', 'Smart'): 66,
#           ('for', 'Smart', 'Home'): 66,
#           ('Smart', 'Home', 'Appliances,abstract'): 66,
#           ('Home', 'Appliances,abstract', 'main'): 66,
#           ('Appliances,abstract', 'main', 'goal'): 66,
#           ('main', 'goal', 'researcher'): 66,
#           ('goal', 'researcher', 'designing'): 66,
#           ('researcher', 'designing', 'smart'): 66,
#           ('designing', 'smart', 'health'): 66,
#           ('smart', 'health', 'care'): 66,
#           ('health', 'care', 'technology'): 66,
#           ('care', 'technology', 'develop'): 66,
#           ('technology', 'develop', 'strategy'): 66,
#           ('develop', 'strategy', 'allowing'): 66,
#           ('strategy', 'allowing', 'early'): 66,
#           ('allowing', 'early', 'detection'): 66,
#           ('early', 'detection', 'avoid'): 66,
#           ('detection', 'avoid', 'problem'): 66,
#           ('avoid', 'problem', 'could'): 66,
#           ('problem', 'could', 'lead'): 66,
#           ('could', 'lead', 'decreased'): 66,
#           ('lead', 'decreased', 'independence'): 66,
#           ('decreased', 'independence', 'medical'): 66,
#           ('independence', 'medical', 'analysis'): 66,
#           ('medical', 'analysis', 'smart'): 66,
#           ('analysis', 'smart', 'sensor'): 66,
#           ('smart', 'sensor', 'intelligent'): 66,
#           ('sensor', 'intelligent', 'software'): 66,
#           ('intelligent', 'software', 'agent'): 66,
#           ('software', 'agent', 'distributed'): 66,
#           ('agent', 'distributed', 'control'): 66,
#           ('distributed', 'control', 'wireless'): 66,
#           ('control', 'wireless', 'comm'): 66,
#           ('wireless', 'comm', '30,30,Smart'): 1,
#           ('comm', '30,30,Smart', 'Sensing'): 1,
#           ('30,30,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '31,31,Structural'): 1,
#           ('system', '31,31,Structural', 'health'): 1,
#           ('31,31,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '32,32,"Whom'): 1,
#           ('wi', '32,32,"Whom', 'You'): 1,
#           ('32,32,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '33,33,A'): 1,
#           ('inv', '33,33,A', 'Survey'): 1,
#           ('33,33,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '34,34,The'): 1,
#           ('biose', '34,34,The', 'SmartPhone'): 1,
#           ('34,34,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '35,35,SMART'): 1,
#           ('alternati', '35,35,SMART', 'SENSING'): 1,
#           ('35,35,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '36,36,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '36,36,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('36,36,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '37,37,SMART'): 1,
#           ('test', '37,37,SMART', 'TECHNOLOGIES'): 1,
#           ('37,37,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '38,38,ADVANCED'): 1,
#           ('presc', '38,38,ADVANCED', 'COMPOSITES'): 1,
#           ('38,38,ADVANCED', 'COMPOSITES', 'FOR'): 1,
#           ('type', 'st', '39,39,Distributed'): 1,
#           ('st', '39,39,Distributed', 'Intelligence'): 1,
#           ('39,39,Distributed', 'Intelligence', 'for'): 1,
#           ('wireless', 'comm', '40,40,Smart'): 1,
#           ('comm', '40,40,Smart', 'Sensing'): 1,
#           ('40,40,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '41,41,Structural'): 1,
#           ('system', '41,41,Structural', 'health'): 1,
#           ('41,41,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '42,42,"Whom'): 1,
#           ('wi', '42,42,"Whom', 'You'): 1,
#           ('42,42,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '43,43,Experimental'): 1,
#           ('inv', '43,43,Experimental', 'Evaluation'): 1,
#           ('43,43,Experimental', 'Evaluation', 'in'): 1,
#           ('article', 'published', '44,44,A'): 1,
#           ('published', '44,44,A', 'Survey'): 1,
#           ('44,44,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '45,45,The'): 1,
#           ('biose', '45,45,The', 'SmartPhone'): 1,
#           ('45,45,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '46,46,SMART'): 1,
#           ('alternati', '46,46,SMART', 'SENSING'): 1,
#           ('46,46,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '47,47,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '47,47,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('47,47,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '48,48,SMART'): 1,
#           ('test', '48,48,SMART', 'TECHNOLOGIES'): 1,
#           ('48,48,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '49,49,ADVANCED'): 1,
#           ('presc', '49,49,ADVANCED', 'COMPOSITES'): 1,
#           ('49,49,ADVANCED', 'COMPOSITES', 'FOR'): 1,
#           ('type', 'st', '50,50,Smart'): 1,
#           ('st', '50,50,Smart', 'Sensing'): 1,
#           ('50,50,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '51,51,Structural'): 1,
#           ('system', '51,51,Structural', 'health'): 1,
#           ('51,51,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '52,52,"Whom'): 1,
#           ('wi', '52,52,"Whom', 'You'): 1,
#           ('52,52,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '53,53,A'): 1,
#           ('inv', '53,53,A', 'Survey'): 1,
#           ('53,53,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '54,54,Is'): 1,
#           ('biose', '54,54,Is', 'Well-being'): 1,
#           ('54,54,Is', 'Well-being', 'U-Shaped'): 1,
#           ('Well-being', 'U-Shaped', 'over'): 2,
#           ('U-Shaped', 'over', 'the'): 2,
#           ('over', 'the', 'Life'): 2,
#           ('the', 'Life', 'Cycle?,present'): 2,
#           ('Life', 'Cycle?,present', 'evidence'): 2,
#           ('Cycle?,present', 'evidence', 'psychological'): 2,
#           ('evidence', 'psychological', 'wellbeing'): 2,
#           ('psychological', 'wellbeing', 'ushaped'): 2,
#           ('wellbeing', 'ushaped', 'life'): 2,
#           ('ushaped', 'life', 'difficulty'): 2,
#           ('life', 'difficulty', 'research'): 2,
#           ('difficulty', 'research', 'issue'): 2,
#           ('research', 'issue', 'likely'): 2,
#           ('issue', 'likely', 'omitted'): 2,
#           ('likely', 'omitted', 'cohort'): 2,
#           ('omitted', 'cohort', 'effect'): 2,
#           ('cohort', 'effect', 'earlier'): 2,
#           ('effect', 'earlier', 'generation'): 2,
#           ('earlier', 'generation', 'may'): 2,
#           ('generation', 'may', 'born'): 2,
#           ('may', 'born', 'say'): 2,
#           ('born', 'say', 'particularly'): 2,
#           ('say', 'particularly', 'good'): 2,
#           ('particularly', 'good', 'bad'): 2,
#           ('good', 'bad', 'time'): 2,
#           ('bad', 'time', 'first'): 2,
#           ('time', 'first', 'using'): 2,
#           ('first', 'using', 'data'): 2,
#           ('using', 'data', 'randomly'): 2,
#           ('data', 'randomly', 'sampled'): 2,
#           ('randomly', 'sampled', '55,55,The'): 1,
#           ('sampled', '55,55,The', 'SmartPhone'): 1,
#           ('55,55,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '56,56,SMART'): 1,
#           ('alternati', '56,56,SMART', 'SENSING'): 1,
#           ('56,56,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '57,57,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '57,57,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('57,57,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '58,58,SMART'): 1,
#           ('test', '58,58,SMART', 'TECHNOLOGIES'): 1,
#           ('58,58,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '59,59,ADVANCED'): 1,
#           ('presc', '59,59,ADVANCED', 'COMPOSITES'): 1,
#           ('59,59,ADVANCED', 'COMPOSITES', 'FOR'): 1,
#           ('type', 'st', '60,60,Smart'): 1,
#           ('st', '60,60,Smart', 'Sensing'): 1,
#           ('60,60,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '61,61,Structural'): 1,
#           ('system', '61,61,Structural', 'health'): 1,
#           ('61,61,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '62,62,"Whom'): 1,
#           ('wi', '62,62,"Whom', 'You'): 1,
#           ('62,62,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '63,63,A'): 1,
#           ('inv', '63,63,A', 'Survey'): 1,
#           ('63,63,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '64,64,The'): 1,
#           ('biose', '64,64,The', 'SmartPhone'): 1,
#           ('64,64,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '65,65,SMART'): 1,
#           ('alternati', '65,65,SMART', 'SENSING'): 1,
#           ('65,65,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '66,66,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '66,66,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('66,66,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '67,67,SMART'): 1,
#           ('test', '67,67,SMART', 'TECHNOLOGIES'): 1,
#           ('67,67,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '68,68,ADVANCED'): 1,
#           ('presc', '68,68,ADVANCED', 'COMPOSITES'): 1,
#           ('68,68,ADVANCED', 'COMPOSITES', 'FOR'): 1,
#           ('type', 'st', '69,69,Distributed'): 1,
#           ('st', '69,69,Distributed', 'Intelligence'): 1,
#           ('69,69,Distributed', 'Intelligence', 'for'): 1,
#           ('wireless', 'comm', '70,70,The'): 1,
#           ('comm', '70,70,The', 'strengthening'): 1,
#           ('70,70,The', 'strengthening', 'the'): 1,
#           ('strengthening', 'the', 'reporting'): 3,
#           ('the', 'reporting', 'of'): 3,
#           ('reporting', 'of', 'observational'): 3,
#           ('of', 'observational', 'studies'): 3,
#           ('observational', 'studies', 'in'): 3,
#           ('studies', 'in', 'epidemiology'): 3,
#           ('in', 'epidemiology', '(STROBE)'): 3,
#           ('epidemiology', '(STROBE)', 'statement:'): 3,
#           ('(STROBE)', 'statement:', 'guidelines'): 3,
#           ('statement:', 'guidelines', 'for'): 3,
#           ('guidelines', 'for', 'reporting'): 3,
#           ('for', 'reporting', 'observational'): 3,
#           ('reporting', 'observational', 'studies.,b'): 3,
#           ('observational', 'studies.,b', 'r'): 3,
#           ('studies.,b', 'r', 'c'): 3,
#           ('r', 'c', 'much'): 3,
#           ('c', 'much', 'biomedical'): 3,
#           ('much', 'biomedical', 'research'): 3,
#           ('biomedical', 'research', 'observational'): 3,
#           ('research', 'observational', 'reporting'): 3,
#           ('observational', 'reporting', 'research'): 3,
#           ('reporting', 'research', 'often'): 3,
#           ('research', 'often', 'inadequate'): 3,
#           ('often', 'inadequate', 'hamper'): 3,
#           ('inadequate', 'hamper', 'assessment'): 3,
#           ('hamper', 'assessment', 'strength'): 3,
#           ('assessment', 'strength', 'weakness'): 3,
#           ('strength', 'weakness', 'study'): 3,
#           ('weakness', 'study', 'generalisability'): 3,
#           ('study', 'generalisability', 'strengthening'): 3,
#           ('generalisability', 'strengthening', 'reporting'): 3,
#           ('strengthening', 'reporting', 'observational'): 3,
#           ('reporting', 'observational', 'study'): 3,
#           ('observational', 'study', 'epidemiology'): 3,
#           ('study', 'epidemiology', 'strobe'): 3,
#           ('epidemiology', 'strobe', 'initi'): 3,
#           ('strobe', 'initi', '71,71,Smart'): 1,
#           ('initi', '71,71,Smart', 'Sensing'): 1,
#           ('71,71,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '72,72,Structural'): 1,
#           ('system', '72,72,Structural', 'health'): 1,
#           ('72,72,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '73,73,"Whom'): 1,
#           ('wi', '73,73,"Whom', 'You'): 1,
#           ('73,73,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '74,74,A'): 1,
#           ('inv', '74,74,A', 'Survey'): 1,
#           ('74,74,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '75,75,The'): 1,
#           ('biose', '75,75,The', 'SmartPhone'): 1,
#           ('75,75,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '76,76,"Indicators'): 1,
#           ('alternati', '76,76,"Indicators', 'for'): 1,
#           ('76,76,"Indicators', 'for', 'Social'): 1,
#           ('for', 'Social', 'and'): 1,
#           ('Social', 'and', 'Economic'): 1,
#           ('and', 'Economic', 'Coping'): 1,
#           ('Economic', 'Coping', 'Capacity'): 1,
#           ('Coping', 'Capacity', '-'): 1,
#           ('Capacity', '-', 'Moving'): 1,
#           ('-', 'Moving', 'Toward'): 1,
#           ('Moving', 'Toward', 'a'): 1,
#           ('Toward', 'a', 'Working'): 1,
#           ('a', 'Working', 'Definition'): 1,
#           ('Working', 'Definition', 'of'): 1,
#           ('Definition', 'of', 'Adaptive'): 1,
#           ('of', 'Adaptive', 'Capacity”,'): 1,
#           ('Adaptive', 'Capacity”,', 'Wesleyan-CMU'): 1,
#           ('Capacity”,', 'Wesleyan-CMU', 'Working'): 1,
#           ('Wesleyan-CMU', 'Working', 'Paper.",abstract'): 1,
#           ('Working', 'Paper.",abstract', 'paper'): 1,
#           ('Paper.",abstract', 'paper', 'offer'): 1,
#           ('paper', 'offer', 'practically'): 1,
#           ('offer', 'practically', 'motivated'): 1,
#           ('practically', 'motivated', 'method'): 1,
#           ('motivated', 'method', 'evaluating'): 1,
#           ('method', 'evaluating', 'system'): 1,
#           ('evaluating', 'system', 'ability'): 1,
#           ('system', 'ability', 'handle'): 1,
#           ('ability', 'handle', 'external'): 1,
#           ('handle', 'external', 'stress'): 1,
#           ('external', 'stress', 'method'): 1,
#           ('stress', 'method', 'designed'): 1,
#           ('method', 'designed', 'potential'): 1,
#           ('designed', 'potential', 'contribution'): 1,
#           ('potential', 'contribution', 'various'): 1,
#           ('contribution', 'various', 'adaptation'): 1,
#           ('various', 'adaptation', 'option'): 1,
#           ('adaptation', 'option', 'improving'): 1,
#           ('option', 'improving', 'system'): 1,
#           ('improving', 'system', 'coping'): 1,
#           ('system', 'coping', 'capacity'): 1,
#           ('coping', 'capacity', 'focusing'): 1,
#           ('capacity', 'focusing', 'attention'): 1,
#           ('focusing', 'attention', 'directly'): 1,
#           ('attention', 'directly', 'u'): 1,
#           ('directly', 'u', '77,77,SMART'): 1,
#           ('u', '77,77,SMART', 'SENSING'): 1,
#           ('77,77,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '78,78,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '78,78,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('78,78,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '79,79,SMART'): 1,
#           ('test', '79,79,SMART', 'TECHNOLOGIES'): 1,
#           ('79,79,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '80,80,Smart'): 1,
#           ('presc', '80,80,Smart', 'Sensing'): 1,
#           ('80,80,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '81,81,Missing'): 1,
#           ('system', '81,81,Missing', 'in'): 1,
#           ('81,81,Missing', 'in', 'Action:'): 1,
#           ('in', 'Action:', 'Teacher'): 2,
#           ('Action:', 'Teacher', 'and'): 2,
#           ('Teacher', 'and', 'Health'): 2,
#           ('and', 'Health', 'Worker'): 2,
#           ('Health', 'Worker', 'Absence'): 2,
#           ('Worker', 'Absence', 'in'): 2,
#           ('Absence', 'in', 'Developing'): 2,
#           ('in', 'Developing', 'Countries,n'): 2,
#           ('Developing', 'Countries,n', 'paper'): 2,
#           ('Countries,n', 'paper', 'report'): 2,
#           ('paper', 'report', 'result'): 2,
#           ('report', 'result', 'survey'): 2,
#           ('result', 'survey', 'enumerator'): 2,
#           ('survey', 'enumerator', 'madeunannounced'): 2,
#           ('enumerator', 'madeunannounced', 'visit'): 2,
#           ('madeunannounced', 'visit', 'primary'): 2,
#           ('visit', 'primary', 'school'): 2,
#           ('primary', 'school', 'health'): 2,
#           ('school', 'health', 'clinic'): 2,
#           ('health', 'clinic', 'bangladeshecuador'): 2,
#           ('clinic', 'bangladeshecuador', 'india'): 2,
#           ('bangladeshecuador', 'india', 'indonesia'): 2,
#           ('india', 'indonesia', 'peru'): 2,
#           ('indonesia', 'peru', 'uganda'): 2,
#           ('peru', 'uganda', 'recorded'): 2,
#           ('uganda', 'recorded', 'whether'): 2,
#           ('recorded', 'whether', 'found'): 2,
#           ('whether', 'found', 'teacher'): 2,
#           ('found', 'teacher', 'health'): 2,
#           ('teacher', 'health', 'worker'): 2,
#           ('health', 'worker', 'facilities1'): 2,
#           ('worker', 'facilities1', 'averaging'): 2,
#           ('facilities1', 'averaging', 'across'): 2,
#           ('averaging', 'across', 'country'): 2,
#           ('across', 'country', 'ab'): 2,
#           ('country', 'ab', '82,82,Structural'): 1,
#           ('ab', '82,82,Structural', 'health'): 1,
#           ('82,82,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '83,83,"Whom'): 1,
#           ('wi', '83,83,"Whom', 'You'): 1,
#           ('83,83,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '84,84,A'): 1,
#           ('inv', '84,84,A', 'Survey'): 1,
#           ('84,84,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '85,85,International'): 1,
#           ('biose', '85,85,International', 'Journal'): 1,
#           ('85,85,International', 'Journal', 'of'): 1,
#           ('Journal', 'of', 'Smart'): 2,
#           ('of', 'Smart', 'Home,many'): 2,
#           ('Smart', 'Home,many', 'people'): 2,
#           ('Home,many', 'people', 'various'): 2,
#           ('people', 'various', 'sector'): 2,
#           ('various', 'sector', 'talking'): 2,
#           ('sector', 'talking', 'smart'): 2,
#           ('talking', 'smart', 'thing'): 2,
#           ('smart', 'thing', 'device'): 2,
#           ('thing', 'device', 'work'): 2,
#           ('device', 'work', 'home'): 2,
#           ('work', 'home', 'education'): 2,
#           ('home', 'education', 'smart'): 2,
#           ('education', 'smart', 'another'): 2,
#           ('smart', 'another', 'word'): 2,
#           ('another', 'word', 'intelligence'): 2,
#           ('word', 'intelligence', 'smart'): 2,
#           ('intelligence', 'smart', 'learning'): 2,
#           ('smart', 'learning', 'defined'): 2,
#           ('learning', 'defined', 'quite'): 2,
#           ('defined', 'quite', 'innovative'): 2,
#           ('quite', 'innovative', 'way'): 2,
#           ('innovative', 'way', 'getting'): 2,
#           ('way', 'getting', 'knowledge'): 2,
#           ('getting', 'knowledge', 'especially'): 2,
#           ('knowledge', 'especially', 'advanced'): 2,
#           ('especially', 'advanced', 'science'): 2,
#           ('advanced', 'science', 'technology'): 2,
#           ('science', 'technology', '86,86,The'): 1,
#           ('technology', '86,86,The', 'SmartPhone'): 1,
#           ('86,86,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '87,87,SMART'): 1,
#           ('alternati', '87,87,SMART', 'SENSING'): 1,
#           ('87,87,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '88,88,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '88,88,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('88,88,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '89,89,SMART'): 1,
#           ('test', '89,89,SMART', 'TECHNOLOGIES'): 1,
#           ('89,89,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '90,90,Smart'): 1,
#           ('presc', '90,90,Smart', 'Sensing'): 1,
#           ('90,90,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '91,91,Structural'): 1,
#           ('system', '91,91,Structural', 'health'): 1,
#           ('91,91,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '92,92,"Whom'): 1,
#           ('wi', '92,92,"Whom', 'You'): 1,
#           ('92,92,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '93,93,Experimental'): 1,
#           ('inv', '93,93,Experimental', 'Evaluation'): 1,
#           ('93,93,Experimental', 'Evaluation', 'in'): 1,
#           ('article', 'published', '94,94,A'): 1,
#           ('published', '94,94,A', 'Survey'): 1,
#           ('94,94,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '95,95,Integrated'): 1,
#           ('biose', '95,95,Integrated', 'Monitoring'): 1,
#           ('95,95,Integrated', 'Monitoring', 'System'): 1,
#           ('Monitoring', 'System', 'for'): 4,
#           ('System', 'for', 'Elderly'): 4,
#           ('for', 'Elderly', 'Care'): 4,
#           ('Elderly', 'Care', 'in'): 4,
#           ('Care', 'in', 'Smart'): 4,
#           ('in', 'Smart', 'Home,exist'): 4,
#           ('Smart', 'Home,exist', 'substantive'): 4,
#           ('Home,exist', 'substantive', 'number'): 4,
#           ('substantive', 'number', 'application'): 4,
#           ('number', 'application', 'designed'): 4,
#           ('application', 'designed', 'smart'): 4,
#           ('designed', 'smart', 'home'): 4,
#           ('smart', 'home', 'may'): 4,
#           ('home', 'may', 'include'): 4,
#           ('may', 'include', 'home'): 4,
#           ('include', 'home', 'monitoring'): 4,
#           ('home', 'monitoring', 'security'): 4,
#           ('monitoring', 'security', 'comfort'): 4,
#           ('security', 'comfort', 'alarm'): 4,
#           ('comfort', 'alarm', 'health'): 4,
#           ('alarm', 'health', 'monitoring'): 4,
#           ('health', 'monitoring', 'etc'): 4,
#           ('monitoring', 'etc', 'research'): 4,
#           ('etc', 'research', 'show'): 4,
#           ('research', 'show', 'number'): 4,
#           ('show', 'number', 'people'): 4,
#           ('number', 'people', 'age'): 4,
#           ('people', 'age', 'around'): 4,
#           ('age', 'around', 'globe'): 4,
#           ('around', 'globe', 'l'): 4,
#           ('globe', 'l', 'ikely'): 4,
#           ('l', 'ikely', 'increase'): 4,
#           ('ikely', 'increase', 'instance'): 4,
#           ('increase', 'instance', '96,96,The'): 1,
#           ('instance', '96,96,The', 'SmartPhone'): 1,
#           ('96,96,The', 'SmartPhone', 'as'): 1,
#           ('accessible', 'alternati', '97,97,SMART'): 1,
#           ('alternati', '97,97,SMART', 'SENSING'): 1,
#           ('97,97,SMART', 'SENSING', 'TECHNOLOGY'): 1,
#           ('system',
#            'em',
#            '98,98,AMultimodalCorpusRecordedinaHealthSmartHome,health'): 1,
#           ('em',
#            '98,98,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart'): 1,
#           ('98,98,AMultimodalCorpusRecordedinaHealthSmartHome,health',
#            'smart',
#            'home'): 1,
#           ('include', 'test', '99,99,SMART'): 1,
#           ('test', '99,99,SMART', 'TECHNOLOGIES'): 1,
#           ('99,99,SMART', 'TECHNOLOGIES', 'FOR'): 1,
#           ('periodic', 'presc', '100,100,Smart'): 1,
#           ('presc', '100,100,Smart', 'Sensing'): 1,
#           ('100,100,Smart', 'Sensing', 'Technology:'): 1,
#           ('networked', 'system', '101,101,Structural'): 1,
#           ('system', '101,101,Structural', 'health'): 1,
#           ('101,101,Structural', 'health', 'monitoring'): 1,
#           ('carry', 'wi', '102,102,"Whom'): 1,
#           ('wi', '102,102,"Whom', 'You'): 1,
#           ('102,102,"Whom', 'You', 'Know'): 1,
#           ('company', 'inv', '103,103,A'): 1,
#           ('inv', '103,103,A', 'Survey'): 1,
#           ('103,103,A', 'Survey', 'on'): 1,
#           ('miniature', 'biose', '104,104,International'): 1,
#           ('biose', '104,104,International', 'Journal'): 1,
#           ('104,104,International', 'Journal', 'of'): 1,
#           ('science', 'technology', '105,105,Research'): 1,
#           ('technology', '105,105,Research', 'Paper'): 1,
#           ('105,105,Research', 'Paper', 'No.'): 1,
#           ('Paper', 'No.', '2008/21'): 1,
#           ('No.', '2008/21', 'Individual'): 1,
#           ('2008/21', 'Individual', 'and'): 1,
#           ('Individual', 'and', 'Collective'): 1,
#           ('and', 'Collective', 'Resources'): 1,
#           ('Collective', 'Resources', 'and'): 1,
#           ('Resources', 'and', 'Health'): 1,
#           ('and', 'Health', 'in'): 1,
#           ('Health', 'in', 'Morocco,interaction'): 1,
#           ('in', 'Morocco,interaction', 'available'): 1,
#           ('Morocco,interaction', 'available', 'individual'): 1,
#           ('available', 'individual', 'collective'): 1,
#           ('individual', 'collective', 'resource'): 1,
#           ('collective', 'resource', 'determination'): 1,
#           ('resource', 'determination', 'health'): 1,
#           ('determination', 'health', 'largely'): 1,
#           ('health', 'largely', 'ignored'): 1,
#           ('largely', 'ignored', 'literature'): 1,
#           ('ignored', 'literature', 'relationship'): 1,
#           ('literature', 'relationship', 'poverty'): 1,
#           ('relationship', 'poverty', 'health'): 1,
#           ('poverty', 'health', 'developing'): 1,
#           ('health', 'developing', 'country'): 1,
#           ('developing', 'country', 'analyse'): 1,
#           ('country', 'analyse', 'role'): 1,
#           ('analyse', 'role', 'public'): 1,
#           ('role', 'public', 'resource'): 1,
#           ('public', 'resource', 'play'): 1,
#           ...})

# %%
#1.2. Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
def probability_bigram():
  for bigram_values in bigra_freq_dist:
    print(("bigram values", bigram_values,"Probability :",bigra_freq_dist[bigram_values]/unigra_freq_dist[(bigram_values[0],)]))
probability_bigram()
# Out:
# ('bigram values', (',Unnamed:', '0,Title,Abstract'), 'Probability :', 1.0)
# ('bigram values', ('0,Title,Abstract', '0,0,The'), 'Probability :', 1.0)
# ('bigram values', ('0,0,The', 'Determinants'), 'Probability :', 1.0)
# ('bigram values', ('Determinants', 'of'), 'Probability :', 1.0)
# ('bigram values', ('of', 'Credit'), 'Probability :', 0.2692307692307692)
# ('bigram values', ('Credit', 'Spread'), 'Probability :', 1.0)
# ('bigram values', ('Spread', 'Changes.,abstract'), 'Probability :', 1.0)
# ('bigram values', ('Changes.,abstract', 'using'), 'Probability :', 1.0)
# ('bigram values', ('using', 'dealer'), 'Probability :', 0.0625)
# ('bigram values', ('dealer', 'quote'), 'Probability :', 1.0)
# ('bigram values', ('quote', 'transaction'), 'Probability :', 1.0)
# ('bigram values', ('transaction', 'price'), 'Probability :', 0.125)
# ('bigram values', ('price', 'straight'), 'Probability :', 1.0)
# ('bigram values', ('straight', 'industrial'), 'Probability :', 1.0)
# ('bigram values', ('industrial', 'bond'), 'Probability :', 1.0)
# ('bigram values', ('bond', 'investigate'), 'Probability :', 1.0)
# ('bigram values', ('investigate', 'determinant'), 'Probability :', 1.0)
# ('bigram values', ('determinant', 'credit'), 'Probability :', 0.875)
# ('bigram values', ('credit', 'spread'), 'Probability :', 1.0)
# ('bigram values', ('spread', 'change'), 'Probability :', 1.0)
# ('bigram values', ('change', 'variable'), 'Probability :', 0.03255813953488372)
# ('bigram values', ('variable', 'theory'), 'Probability :', 0.875)
# ('bigram values', ('theory', 'determine'), 'Probability :', 1.0)
# ('bigram values', ('determine', 'credit'), 'Probability :', 1.0)
# ('bigram values', ('change', 'rather'), 'Probability :', 0.03255813953488372)
# ('bigram values', ('rather', 'limited'), 'Probability :', 0.125)
# ('bigram values', ('limited', 'explanatory'), 'Probability :', 1.0)
# ('bigram values', ('explanatory', 'power'), 'Probability :', 1.0)
# ('bigram values', ('power', 'residual'), 'Probability :', 0.7777777777777778)
# ('bigram values', ('residual', 'regression'), 'Probability :', 1.0)
# ('bigram values', ('regression', '1,1,Smart'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('1,1,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('Sensing', 'Technology:'), 'Probability :', 1.0)
# ('bigram values', ('Technology:', 'Opportunities'), 'Probability :', 1.0)
# ('bigram values', ('Opportunities', 'and'), 'Probability :', 1.0)
# ('bigram values', ('and', 'Challenges,abstract'), 'Probability :', 0.36101083032490977)
# ('bigram values', ('Challenges,abstract', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('smart', 'sensor'), 'Probability :', 0.3128491620111732)
# ('bigram values', ('sensor', 'embedded'), 'Probability :', 0.5434782608695652)
# ('bigram values', ('embedded', 'microprocessor'), 'Probability :', 0.9950248756218906)
# ('bigram values', ('microprocessor', 'wireless'), 'Probability :', 1.0)
# ('bigram values', ('wireless', 'communication'), 'Probability :', 0.7490636704119851)
# ('bigram values', ('communication', 'link'), 'Probability :', 1.0)
# ('bigram values', ('link', 'potential'), 'Probability :', 1.0)
# ('bigram values', ('potential', 'change'), 'Probability :', 0.423728813559322)
# ('bigram values', ('change', 'fundamentally'), 'Probability :', 0.46511627906976744)
# ('bigram values', ('fundamentally', 'way'), 'Probability :', 0.5)
# ('bigram values', ('way', 'civil'), 'Probability :', 0.9852216748768473)
# ('bigram values', ('civil', 'infrastructure'), 'Probability :', 0.6677740863787376)
# ('bigram values', ('infrastructure', 'system'), 'Probability :', 0.9950248756218906)
# ('bigram values', ('system', 'monitored'), 'Probability :', 0.31007751937984496)
# ('bigram values', ('monitored', 'controlled'), 'Probability :', 1.0)
# ('bigram values', ('controlled', 'maintained'), 'Probability :', 1.0)
# ('bigram values', ('maintained', 'indeed'), 'Probability :', 1.0)
# ('bigram values', ('indeed', 'national'), 'Probability :', 1.0)
# ('bigram values', ('national', 'research'), 'Probability :', 0.9950248756218906)
# ('bigram values', ('research', 'council'), 'Probability :', 0.3160377358490566)
# ('bigram values', ('council', 'report'), 'Probability :', 0.9950248756218906)
# ('bigram values', ('report', 'noted'), 'Probability :', 0.9803921568627451)
# ('bigram values', ('noted', 'use'), 'Probability :', 1.0)
# ('bigram values', ('use', 'networked'), 'Probability :', 0.6514657980456026)
# ('bigram values', ('networked', 'system'), 'Probability :', 1.0)
# ('bigram values', ('system', '2,2,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('2,2,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('health', 'monitoring'), 'Probability :', 0.4265536723163842)
# ('bigram values', ('monitoring', 'using'), 'Probability :', 0.32679738562091504)
# ('bigram values', ('using', 'smart'), 'Probability :', 0.9017857142857143)
# ('bigram values', ('smart', 'sensors,excellence'), 'Probability :', 0.186219739292365)
# ('bigram values', ('sensors,excellence', 'research'), 'Probability :', 1.0)
# ('bigram values', ('research', 'education'), 'Probability :', 0.15723270440251572)
# ('bigram values', ('education', 'contributed'), 'Probability :', 0.9803921568627451)
# ('bigram values', ('contributed', 'greatly'), 'Probability :', 1.0)
# ('bigram values', ('greatly', 'stateoftheart'), 'Probability :', 1.0)
# ('bigram values', ('stateoftheart', 'civil'), 'Probability :', 1.0)
# ('bigram values', ('civil', 'engineering'), 'Probability :', 0.33222591362126247)
# ('bigram values', ('engineering', 'completed'), 'Probability :', 1.0)
# ('bigram values', ('completed', 'extended'), 'Probability :', 1.0)
# ('bigram values', ('extended', 'structural'), 'Probability :', 0.9900990099009901)
# ('bigram values', ('structural', 'testing'), 'Probability :', 0.5102040816326531)
# ('bigram values', ('testing', 'area'), 'Probability :', 1.0)
# ('bigram values', ('area', 'laboratory'), 'Probability :', 0.4975124378109453)
# ('bigram values', ('laboratory', 'versatile'), 'Probability :', 1.0)
# ('bigram values', ('versatile', 'strongfloorwall'), 'Probability :', 1.0)
# ('bigram values', ('strongfloorwall', 'threestory'), 'Probability :', 1.0)
# ('bigram values', ('threestory', 'clear'), 'Probability :', 1.0)
# ('bigram values', ('clear', 'height'), 'Probability :', 1.0)
# ('bigram values', ('height', 'used'), 'Probability :', 1.0)
# ('bigram values', ('used', 'carry'), 'Probability :', 0.36496350364963503)
# ('bigram values', ('carry', 'wi'), 'Probability :', 0.9900990099009901)
# ('bigram values', ('wi', '3,3,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('3,3,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('You', 'Know'), 'Probability :', 1.0)
# ('bigram values', ('Know', 'Matters:'), 'Probability :', 1.0)
# ('bigram values', ('Matters:', 'Venture'), 'Probability :', 1.0)
# ('bigram values', ('Venture', 'Capital'), 'Probability :', 1.0)
# ('bigram values', ('Capital', 'Networks'), 'Probability :', 1.0)
# ('bigram values', ('Networks', 'and'), 'Probability :', 1.0)
# ('bigram values', ('and', 'Investment'), 'Probability :', 0.17689530685920576)
# ('bigram values', ('Investment', 'Performance,",abstract'), 'Probability :', 1.0)
# ('bigram values', ('Performance,",abstract', 'many'), 'Probability :', 1.0)
# ('bigram values', ('many', 'financial'), 'Probability :', 0.2024793388429752)
# ('bigram values', ('financial', 'market'), 'Probability :', 1.0)
# ('bigram values', ('market', 'characterized'), 'Probability :', 1.0)
# ('bigram values', ('characterized', 'strong'), 'Probability :', 1.0)
# ('bigram values', ('strong', 'relationship'), 'Probability :', 1.0)
# ('bigram values', ('relationship', 'network'), 'Probability :', 0.49)
# ('bigram values', ('network', 'rather'), 'Probability :', 0.98)
# ('bigram values', ('rather', 'armslength'), 'Probability :', 0.875)
# ('bigram values', ('armslength', 'spotmarket'), 'Probability :', 1.0)
# ('bigram values', ('spotmarket', 'transaction'), 'Probability :', 1.0)
# ('bigram values', ('transaction', 'examine'), 'Probability :', 0.875)
# ('bigram values', ('examine', 'performance'), 'Probability :', 1.0)
# ('bigram values', ('performance', 'consequence'), 'Probability :', 1.0)
# ('bigram values', ('consequence', 'organizational'), 'Probability :', 0.98)
# ('bigram values', ('organizational', 'choice'), 'Probability :', 1.0)
# ('bigram values', ('choice', 'context'), 'Probability :', 1.0)
# ('bigram values', ('context', 'relationship'), 'Probability :', 1.0)
# ('bigram values', ('relationship', 'established'), 'Probability :', 0.49)
# ('bigram values', ('established', 'vcs'), 'Probability :', 0.9245283018867925)
# ('bigram values', ('vcs', 'syndicate'), 'Probability :', 1.0)
# ('bigram values', ('syndicate', 'portfolio'), 'Probability :', 1.0)
# ('bigram values', ('portfolio', 'company'), 'Probability :', 1.0)
# ('bigram values', ('company', 'inv'), 'Probability :', 1.0)
# ('bigram values', ('inv', '4,4,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('4,4,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('Survey', 'on'), 'Probability :', 0.9803921568627451)
# ('bigram values', ('on', 'Wearable'), 'Probability :', 0.9900990099009901)
# ('bigram values', ('Wearable', 'Sensor-Based'), 'Probability :', 1.0)
# ('bigram values', ('Sensor-Based', 'Systems'), 'Probability :', 1.0)
# ('bigram values', ('Systems', 'for'), 'Probability :', 1.0)
# ('bigram values', ('for', 'Health'), 'Probability :', 0.35842293906810035)
# ('bigram values', ('Health', 'Monitoring'), 'Probability :', 0.9090909090909091)
# ('bigram values', ('Monitoring', 'and'), 'Probability :', 0.9615384615384616)
# ('bigram values', ('and', 'Prognosis,abstractthe'), 'Probability :', 0.36101083032490977)
# ('bigram values', ('Prognosis,abstractthe', 'design'), 'Probability :', 1.0)
# ('bigram values', ('design', 'development'), 'Probability :', 0.970873786407767)
# ('bigram values', ('development', 'wearable'), 'Probability :', 0.9615384615384616)
# ('bigram values', ('wearable', 'biosensor'), 'Probability :', 0.5)
# ('bigram values', ('biosensor', 'system'), 'Probability :', 1.0)
# ('bigram values', ('system', 'health'), 'Probability :', 0.15503875968992248)
# ('bigram values', ('monitoring', 'garnered'), 'Probability :', 0.32679738562091504)
# ('bigram values', ('garnered', 'lot'), 'Probability :', 1.0)
# ('bigram values', ('lot', 'attention'), 'Probability :', 1.0)
# ('bigram values', ('attention', 'scientific'), 'Probability :', 0.9803921568627451)
# ('bigram values', ('scientific', 'community'), 'Probability :', 1.0)
# ('bigram values', ('community', 'industry'), 'Probability :', 1.0)
# ('bigram values', ('industry', 'last'), 'Probability :', 1.0)
# ('bigram values', ('last', 'year'), 'Probability :', 1.0)
# ('bigram values', ('year', 'mainly'), 'Probability :', 0.970873786407767)
# ('bigram values', ('mainly', 'motivated'), 'Probability :', 1.0)
# ('bigram values', ('motivated', 'increasing'), 'Probability :', 0.9900990099009901)
# ('bigram values', ('increasing', 'healthcare'), 'Probability :', 1.0)
# ('bigram values', ('healthcare', 'cost'), 'Probability :', 1.0)
# ('bigram values', ('cost', 'propelled'), 'Probability :', 0.5128205128205128)
# ('bigram values', ('propelled', 'recent'), 'Probability :', 1.0)
# ('bigram values', ('recent', 'technological'), 'Probability :', 0.4854368932038835)
# ('bigram values', ('technological', 'advance'), 'Probability :', 1.0)
# ('bigram values', ('advance', 'miniature'), 'Probability :', 0.5128205128205128)
# ('bigram values', ('miniature', 'biose'), 'Probability :', 1.0)
# ('bigram values', ('biose', '5,5,The'), 'Probability :', 0.01)
# ('bigram values', ('5,5,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('SmartPhone', 'as'), 'Probability :', 1.0)
# ('bigram values', ('as', 'a'), 'Probability :', 1.0)
# ('bigram values', ('a', 'platform'), 'Probability :', 0.9259259259259259)
# ('bigram values', ('platform', 'for'), 'Probability :', 1.0)
# ('bigram values', ('for', 'wearable'), 'Probability :', 0.35842293906810035)
# ('bigram values', ('wearable', 'cameras'), 'Probability :', 0.5)
# ('bigram values', ('cameras', 'in'), 'Probability :', 1.0)
# ('bigram values', ('in', 'health'), 'Probability :', 0.7769230769230769)
# ('bigram values', ('health', 'research,background'), 'Probability :', 0.14124293785310735)
# ('bigram values', ('research,background', 'sensecam'), 'Probability :', 1.0)
# ('bigram values', ('sensecam', 'small'), 'Probability :', 0.5)
# ('bigram values', ('small', 'camera'), 'Probability :', 1.0)
# ('bigram values', ('camera', 'worn'), 'Probability :', 1.0)
# ('bigram values', ('worn', 'chest'), 'Probability :', 1.0)
# ('bigram values', ('chest', 'via'), 'Probability :', 1.0)
# ('bigram values', ('via', 'lanyard'), 'Probability :', 0.9803921568627451)
# ('bigram values', ('lanyard', 'increasingly'), 'Probability :', 1.0)
# ('bigram values', ('increasingly', 'deployed'), 'Probability :', 0.746268656716418)
# ('bigram values', ('deployed', 'health'), 'Probability :', 1.0)
# ('bigram values', ('health', 'research'), 'Probability :', 0.14124293785310735)
# ('bigram values', ('research', 'however'), 'Probability :', 0.15723270440251572)
# ('bigram values', ('however', 'sensecam'), 'Probability :', 0.5025125628140703)
# ('bigram values', ('sensecam', 'yet'), 'Probability :', 0.5)
# ('bigram values', ('yet', 'widespread'), 'Probability :', 1.0)
# ('bigram values', ('widespread', 'use'), 'Probability :', 1.0)
# ('bigram values', ('use', 'due'), 'Probability :', 0.3257328990228013)
# ('bigram values', ('due', 'variety'), 'Probability :', 0.3003003003003003)
# ('bigram values', ('variety', 'factor'), 'Probability :', 1.0)
# ('bigram values', ('factor', 'proposed'), 'Probability :', 0.9900990099009901)
# ('bigram values', ('proposed', 'ubiquitous'), 'Probability :', 0.5291005291005291)
# ('bigram values', ('ubiquitous', 'smartphone'), 'Probability :', 1.0)
# ('bigram values', ('smartphone', 'provide'), 'Probability :', 1.0)
# ('bigram values', ('provide', 'accessible'), 'Probability :', 0.9803921568627451)
# ('bigram values', ('accessible', 'alternati'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '6,6,SMART'), 'Probability :', 0.01)
# ('bigram values', ('6,6,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('SENSING', 'TECHNOLOGY'), 'Probability :', 1.0)
# ('bigram values', ('TECHNOLOGY', 'FOR'), 'Probability :', 1.0)
# ('bigram values', ('FOR', 'STRUCTURAL'), 'Probability :', 0.6914893617021277)
# ('bigram values', ('STRUCTURAL', 'HEALTH'), 'Probability :', 1.0)
# ('bigram values', ('HEALTH', 'MONITORING,smart'), 'Probability :', 0.5128205128205128)
# ('bigram values', ('MONITORING,smart', 'sensor'), 'Probability :', 1.0)
# ('bigram values', ('potential', 'fundamentally'), 'Probability :', 0.423728813559322)
# ('bigram values', ('fundamentally', 'change'), 'Probability :', 0.5)
# ('bigram values', ('change', 'way'), 'Probability :', 0.46511627906976744)
# ('bigram values', ('system', 'em'), 'Probability :', 0.15503875968992248)
# ('bigram values', ('em', '7,7,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('7,7,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('smart', 'home'), 'Probability :', 0.19180633147113593)
# ('bigram values', ('home', 'nowadays'), 'Probability :', 0.4647887323943662)
# ('bigram values', ('nowadays', 'explored'), 'Probability :', 1.0)
# ('bigram values', ('explored', 'research'), 'Probability :', 1.0)
# ('bigram values', ('research', 'area'), 'Probability :', 0.15566037735849056)
# ('bigram values', ('area', 'due'), 'Probability :', 0.4925373134328358)
# ('bigram values', ('due', 'need'), 'Probability :', 0.2972972972972973)
# ('bigram values', ('need', 'home'), 'Probability :', 0.99)
# ('bigram values', ('home', 'automation'), 'Probability :', 0.4647887323943662)
# ('bigram values', ('automation', 'telemedicine'), 'Probability :', 1.0)
# ('bigram values', ('telemedicine', 'support'), 'Probability :', 1.0)
# ('bigram values', ('support', 'people'), 'Probability :', 0.9428571428571428)
# ('bigram values', ('people', 'loss'), 'Probability :', 0.868421052631579)
# ('bigram values', ('loss', 'autonomy'), 'Probability :', 0.99)
# ('bigram values', ('autonomy', 'also'), 'Probability :', 1.0)
# ('bigram values', ('also', 'due'), 'Probability :', 0.9801980198019802)
# ('bigram values', ('due', 'evolution'), 'Probability :', 0.2972972972972973)
# ('bigram values', ('evolution', 'technology'), 'Probability :', 1.0)
# ('bigram values', ('technology', 'resulted'), 'Probability :', 0.33)
# ('bigram values', ('resulted', 'cheap'), 'Probability :', 1.0)
# ('bigram values', ('cheap', 'efficient'), 'Probability :', 1.0)
# ('bigram values', ('efficient', 'sensor'), 'Probability :', 1.0)
# ('bigram values', ('sensor', 'however'), 'Probability :', 0.26902173913043476)
# ('bigram values', ('however', 'many'), 'Probability :', 0.49748743718592964)
# ('bigram values', ('many', 'study'), 'Probability :', 0.4090909090909091)
# ('bigram values', ('study', 'include'), 'Probability :', 0.908256880733945)
# ('bigram values', ('include', 'test'), 'Probability :', 0.9611650485436893)
# ('bigram values', ('test', '8,8,SMART'), 'Probability :', 0.01)
# ('bigram values', ('8,8,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('TECHNOLOGIES', 'FOR'), 'Probability :', 1.0)
# ('bigram values', ('HEALTH', 'MONITORING'), 'Probability :', 0.48717948717948717)
# ('bigram values', ('MONITORING', 'OF'), 'Probability :', 1.0)
# ('bigram values', ('OF', 'AEROSPACE'), 'Probability :', 1.0)
# ('bigram values', ('AEROSPACE', 'STRUCTURES,paper'), 'Probability :', 1.0)
# ('bigram values', ('STRUCTURES,paper', 'present'), 'Probability :', 1.0)
# ('bigram values', ('present', 'recent'), 'Probability :', 0.9405940594059405)
# ('bigram values', ('recent', 'advance'), 'Probability :', 0.46116504854368934)
# ('bigram values', ('advance', 'structural'), 'Probability :', 0.48717948717948717)
# ('bigram values', ('structural', 'health'), 'Probability :', 0.4897959183673469)
# ('bigram values', ('monitoring', 'shm'), 'Probability :', 0.3137254901960784)
# ('bigram values', ('shm', 'project'), 'Probability :', 0.4973821989528796)
# ('bigram values', ('project', 'within'), 'Probability :', 0.4973821989528796)
# ('bigram values', ('within', 'consortium'), 'Probability :', 0.7307692307692307)
# ('bigram values', ('consortium', 'research'), 'Probability :', 1.0)
# ('bigram values', ('research', 'innovation'), 'Probability :', 0.14937106918238993)
# ('bigram values', ('innovation', 'aerospace'), 'Probability :', 1.0)
# ('bigram values', ('aerospace', 'québec'), 'Probability :', 1.0)
# ('bigram values', ('québec', 'criaq'), 'Probability :', 1.0)
# ('bigram values', ('criaq', 'project'), 'Probability :', 1.0)
# ('bigram values', ('project', 'aim'), 'Probability :', 0.4973821989528796)
# ('bigram values', ('aim', 'developing'), 'Probability :', 0.9895833333333334)
# ('bigram values', ('developing', 'technology'), 'Probability :', 0.979381443298969)
# ('bigram values', ('technology', 'shm'), 'Probability :', 0.31666666666666665)
# ('bigram values', ('shm', 'system'), 'Probability :', 0.4973821989528796)
# ('bigram values', ('system', 'potentially'), 'Probability :', 0.14728682170542637)
# ('bigram values', ('potentially', 'reducing'), 'Probability :', 1.0)
# ('bigram values', ('reducing', 'high'), 'Probability :', 1.0)
# ('bigram values', ('high', 'cost'), 'Probability :', 0.979381443298969)
# ('bigram values', ('cost', 'associated'), 'Probability :', 0.48717948717948717)
# ('bigram values', ('associated', 'periodic'), 'Probability :', 1.0)
# ('bigram values', ('periodic', 'presc'), 'Probability :', 1.0)
# ('bigram values', ('presc', '9,9,Occasional'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('9,9,Occasional', 'Paper'), 'Probability :', 1.0)
# ('bigram values', ('Paper', '11,organic'), 'Probability :', 0.1)
# ('bigram values', ('11,organic', 'resourceconserving'), 'Probability :', 1.0)
# ('bigram values', ('resourceconserving', 'agriculture'), 'Probability :', 1.0)
# ('bigram values', ('agriculture', 'improve'), 'Probability :', 1.0)
# ('bigram values', ('improve', 'livelihood'), 'Probability :', 0.5)
# ('bigram values', ('livelihood', 'metaanalysis'), 'Probability :', 1.0)
# ('bigram values', ('metaanalysis', 'conceptual'), 'Probability :', 1.0)
# ('bigram values', ('conceptual', 'framework'), 'Probability :', 1.0)
# ('bigram values', ('framework', 'sitespecific'), 'Probability :', 1.0)
# ('bigram values', ('sitespecific', 'evaluation'), 'Probability :', 1.0)
# ('bigram values', ('evaluation', 'mica'), 'Probability :', 0.1)
# ('bigram values', ('mica', 'bennett'), 'Probability :', 1.0)
# ('bigram values', ('bennett', 'steven'), 'Probability :', 1.0)
# ('bigram values', ('steven', 'franzelthe'), 'Probability :', 1.0)
# ('bigram values', ('franzelthe', 'world'), 'Probability :', 1.0)
# ('bigram values', ('world', 'agroforestry'), 'Probability :', 0.125)
# ('bigram values', ('agroforestry', 'centre'), 'Probability :', 1.0)
# ('bigram values', ('centre', 'autonomous'), 'Probability :', 0.5)
# ('bigram values', ('autonomous', 'nonprofit'), 'Probability :', 1.0)
# ('bigram values', ('nonprofit', 'research'), 'Probability :', 1.0)
# ('bigram values', ('research', 'organization'), 'Probability :', 0.0015723270440251573)
# ('bigram values', ('organization', 'aim'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('aim', 'bring'), 'Probability :', 0.010416666666666666)
# ('bigram values', ('bring', 'rural'), 'Probability :', 1.0)
# ('bigram values', ('rural', 'transformation'), 'Probability :', 0.2)
# ('bigram values', ('transformation', 'deve'), 'Probability :', 1.0)
# ('bigram values', ('deve', '10,10,The'), 'Probability :', 1.0)
# ('bigram values', ('10,10,The', 'Determinants'), 'Probability :', 1.0)
# ('bigram values', ('regression', '11,11,"Stress,'), 'Probability :', 0.14285714285714285)
# ('bigram values', ('11,11,"Stress,', 'coping'), 'Probability :', 1.0)
# ('bigram values', ('coping', 'and'), 'Probability :', 0.75)
# ('bigram values', ('and', 'social'), 'Probability :', 0.010830324909747292)
# ('bigram values', ('social', 'support'), 'Probability :', 0.75)
# ('bigram values', ('support', 'processes:'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('processes:', 'Where'), 'Probability :', 1.0)
# ('bigram values', ('Where', 'are'), 'Probability :', 1.0)
# ('bigram values', ('are', 'we?'), 'Probability :', 1.0)
# ('bigram values', ('we?', 'What'), 'Probability :', 1.0)
# ('bigram values', ('What', 'next?",jstor'), 'Probability :', 1.0)
# ('bigram values', ('next?",jstor', 'notforprofit'), 'Probability :', 1.0)
# ('bigram values', ('notforprofit', 'service'), 'Probability :', 1.0)
# ('bigram values', ('service', 'help'), 'Probability :', 0.5)
# ('bigram values', ('help', 'scholar'), 'Probability :', 1.0)
# ('bigram values', ('scholar', 'researcher'), 'Probability :', 1.0)
# ('bigram values', ('researcher', 'student'), 'Probability :', 0.04285714285714286)
# ('bigram values', ('student', 'discover'), 'Probability :', 1.0)
# ('bigram values', ('discover', 'use'), 'Probability :', 1.0)
# ('bigram values', ('use', 'build'), 'Probability :', 0.009771986970684038)
# ('bigram values', ('build', 'upon'), 'Probability :', 1.0)
# ('bigram values', ('upon', 'wide'), 'Probability :', 1.0)
# ('bigram values', ('wide', 'range'), 'Probability :', 1.0)
# ('bigram values', ('range', 'content'), 'Probability :', 0.75)
# ('bigram values', ('content', 'trusted'), 'Probability :', 1.0)
# ('bigram values', ('trusted', 'digital'), 'Probability :', 1.0)
# ('bigram values', ('digital', 'archive'), 'Probability :', 1.0)
# ('bigram values', ('archive', 'use'), 'Probability :', 1.0)
# ('bigram values', ('use', 'information'), 'Probability :', 0.009771986970684038)
# ('bigram values', ('information', 'technology'), 'Probability :', 0.4868421052631579)
# ('bigram values', ('technology', 'tool'), 'Probability :', 0.01)
# ('bigram values', ('tool', 'increase'), 'Probability :', 1.0)
# ('bigram values', ('increase', 'productivity'), 'Probability :', 0.375)
# ('bigram values', ('productivity', 'facilitate'), 'Probability :', 0.75)
# ('bigram values', ('facilitate', 'new'), 'Probability :', 1.0)
# ('bigram values', ('new', 'form'), 'Probability :', 0.75)
# ('bigram values', ('form', 'scholarship'), 'Probability :', 1.0)
# ('bigram values', ('scholarship', 'information'), 'Probability :', 1.0)
# ('bigram values', ('information', 'j'), 'Probability :', 0.039473684210526314)
# ('bigram values', ('j', '12,12,Smart'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('12,12,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '13,13,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('13,13,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '14,14,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('14,14,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '15,15,Experimental'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('15,15,Experimental', 'Evaluation'), 'Probability :', 1.0)
# ('bigram values', ('Evaluation', 'in'), 'Probability :', 0.875)
# ('bigram values', ('in', 'Computer'), 'Probability :', 0.05384615384615385)
# ('bigram values', ('Computer', 'Science:'), 'Probability :', 1.0)
# ('bigram values', ('Science:', 'A'), 'Probability :', 1.0)
# ('bigram values', ('A', 'Quantitative'), 'Probability :', 0.16279069767441862)
# ('bigram values', ('Quantitative', 'Study,survey'), 'Probability :', 1.0)
# ('bigram values', ('Study,survey', 'recent'), 'Probability :', 1.0)
# ('bigram values', ('recent', 'research'), 'Probability :', 0.03398058252427184)
# ('bigram values', ('research', 'article'), 'Probability :', 0.0110062893081761)
# ('bigram values', ('article', 'suggests'), 'Probability :', 0.5)
# ('bigram values', ('suggests', 'computer'), 'Probability :', 1.0)
# ('bigram values', ('computer', 'scientist'), 'Probability :', 0.5)
# ('bigram values', ('scientist', 'publish'), 'Probability :', 1.0)
# ('bigram values', ('publish', 'relatively'), 'Probability :', 1.0)
# ('bigram values', ('relatively', 'paper'), 'Probability :', 1.0)
# ('bigram values', ('paper', 'experimentally'), 'Probability :', 0.2)
# ('bigram values', ('experimentally', 'validated'), 'Probability :', 1.0)
# ('bigram values', ('validated', 'result'), 'Probability :', 1.0)
# ('bigram values', ('result', 'survey'), 'Probability :', 1.0)
# ('bigram values', ('survey', 'includes'), 'Probability :', 0.6363636363636364)
# ('bigram values', ('includes', 'complete'), 'Probability :', 0.875)
# ('bigram values', ('complete', 'volume'), 'Probability :', 1.0)
# ('bigram values', ('volume', 'several'), 'Probability :', 1.0)
# ('bigram values', ('several', 'refereed'), 'Probability :', 0.875)
# ('bigram values', ('refereed', 'computer'), 'Probability :', 1.0)
# ('bigram values', ('computer', 'science'), 'Probability :', 0.5)
# ('bigram values', ('science', 'journal'), 'Probability :', 0.7777777777777778)
# ('bigram values', ('journal', 'conference'), 'Probability :', 1.0)
# ('bigram values', ('conference', 'title'), 'Probability :', 1.0)
# ('bigram values', ('title', 'drawn'), 'Probability :', 1.0)
# ('bigram values', ('drawn', 'random'), 'Probability :', 1.0)
# ('bigram values', ('random', 'article'), 'Probability :', 1.0)
# ('bigram values', ('article', 'published'), 'Probability :', 0.5)
# ('bigram values', ('published', '16,16,A'), 'Probability :', 0.125)
# ('bigram values', ('16,16,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '17,17,Compassionate'), 'Probability :', 0.01)
# ('bigram values', ('17,17,Compassionate', 'mind'), 'Probability :', 1.0)
# ('bigram values', ('mind', 'training'), 'Probability :', 1.0)
# ('bigram values', ('training', 'for'), 'Probability :', 0.5)
# ('bigram values', ('for', 'people'), 'Probability :', 0.0035842293906810036)
# ('bigram values', ('people', 'with'), 'Probability :', 0.008771929824561403)
# ('bigram values', ('with', 'high'), 'Probability :', 0.5)
# ('bigram values', ('high', 'shame'), 'Probability :', 0.020618556701030927)
# ('bigram values', ('shame', 'and'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('and', 'self-criticism:'), 'Probability :', 0.0036101083032490976)
# ('bigram values', ('self-criticism:', 'Overview'), 'Probability :', 1.0)
# ('bigram values', ('Overview', 'and'), 'Probability :', 1.0)
# ('bigram values', ('and', 'pilot'), 'Probability :', 0.0036101083032490976)
# ('bigram values', ('pilot', 'study'), 'Probability :', 0.5)
# ('bigram values', ('study', 'of'), 'Probability :', 0.009174311926605505)
# ('bigram values', ('of', 'a'), 'Probability :', 0.11538461538461539)
# ('bigram values', ('a', 'group'), 'Probability :', 0.009259259259259259)
# ('bigram values', ('group', 'of'), 'Probability :', 1.0)
# ('bigram values', ('of', 'therapy'), 'Probability :', 0.038461538461538464)
# ('bigram values', ('therapy', 'approach,compassionate'), 'Probability :', 1.0)
# ('bigram values', ('approach,compassionate', 'mind'), 'Probability :', 1.0)
# ('bigram values', ('training', 'cmt'), 'Probability :', 0.5)
# ('bigram values', ('cmt', 'developed'), 'Probability :', 1.0)
# ('bigram values', ('developed', 'people'), 'Probability :', 1.0)
# ('bigram values', ('people', 'high'), 'Probability :', 0.008771929824561403)
# ('bigram values', ('shame', 'selfcriticism'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('selfcriticism', 'whose'), 'Probability :', 0.5)
# ('bigram values', ('whose', 'problem'), 'Probability :', 1.0)
# ('bigram values', ('problem', 'tend'), 'Probability :', 0.014492753623188406)
# ('bigram values', ('tend', 'chronic'), 'Probability :', 1.0)
# ('bigram values', ('chronic', 'find'), 'Probability :', 1.0)
# ('bigram values', ('find', 'selfwarmth'), 'Probability :', 0.5)
# ('bigram values', ('selfwarmth', 'selfacceptance'), 'Probability :', 1.0)
# ('bigram values', ('selfacceptance', 'difficult'), 'Probability :', 1.0)
# ('bigram values', ('difficult', 'andor'), 'Probability :', 1.0)
# ('bigram values', ('andor', 'frightening'), 'Probability :', 1.0)
# ('bigram values', ('frightening', 'paper'), 'Probability :', 1.0)
# ('bigram values', ('paper', 'offer'), 'Probability :', 0.05714285714285714)
# ('bigram values', ('offer', 'short'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('short', 'overview'), 'Probability :', 0.5)
# ('bigram values', ('overview', 'role'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('role', 'shame'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('selfcriticism', 'psychological'), 'Probability :', 0.5)
# ('bigram values', ('psychological', 'dif'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('dif', '18,18,The'), 'Probability :', 1.0)
# ('bigram values', ('18,18,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '19,19,SMART'), 'Probability :', 0.01)
# ('bigram values', ('19,19,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '20,20,Smart'), 'Probability :', 0.01)
# ('bigram values', ('20,20,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '21,21,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('21,21,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '22,22,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('22,22,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '23,23,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('23,23,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '24,24,The'), 'Probability :', 0.01)
# ('bigram values', ('24,24,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '25,25,SMART'), 'Probability :', 0.01)
# ('bigram values', ('25,25,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '26,26,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('26,26,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '27,27,SMART'), 'Probability :', 0.01)
# ('bigram values', ('27,27,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '28,28,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('28,28,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('COMPOSITES', 'FOR'), 'Probability :', 1.0)
# ('bigram values', ('FOR', 'SMART'), 'Probability :', 0.30851063829787234)
# ('bigram values', ('SMART', 'STRUCTURES,summary'), 'Probability :', 0.71900826446281)
# ('bigram values', ('STRUCTURES,summary', 'many'), 'Probability :', 1.0)
# ('bigram values', ('many', 'advanced'), 'Probability :', 0.359504132231405)
# ('bigram values', ('advanced', 'composite'), 'Probability :', 0.9775280898876404)
# ('bigram values', ('composite', 'material'), 'Probability :', 0.9775280898876404)
# ('bigram values', ('material', 'proposed'), 'Probability :', 0.9886363636363636)
# ('bigram values', ('proposed', 'smart'), 'Probability :', 0.4708994708994709)
# ('bigram values', ('smart', 'structure'), 'Probability :', 0.16201117318435754)
# ('bigram values', ('structure', 'beside'), 'Probability :', 0.5)
# ('bigram values', ('beside', 'aramid'), 'Probability :', 1.0)
# ('bigram values', ('aramid', 'glass'), 'Probability :', 1.0)
# ('bigram values', ('glass', 'carbon'), 'Probability :', 1.0)
# ('bigram values', ('carbon', 'fibre'), 'Probability :', 1.0)
# ('bigram values', ('fibre', 'reinforced'), 'Probability :', 1.0)
# ('bigram values', ('reinforced', 'polymer'), 'Probability :', 1.0)
# ('bigram values', ('polymer', 'frp'), 'Probability :', 1.0)
# ('bigram values', ('frp', 'used'), 'Probability :', 0.5)
# ('bigram values', ('used', 'replace'), 'Probability :', 0.3175182481751825)
# ('bigram values', ('replace', 'steel'), 'Probability :', 1.0)
# ('bigram values', ('steel', 'bar'), 'Probability :', 1.0)
# ('bigram values', ('bar', 'strand'), 'Probability :', 1.0)
# ('bigram values', ('strand', 'wire'), 'Probability :', 1.0)
# ('bigram values', ('wire', 'tendon'), 'Probability :', 1.0)
# ('bigram values', ('tendon', 'structure'), 'Probability :', 1.0)
# ('bigram values', ('structure', 'frp'), 'Probability :', 0.5)
# ('bigram values', ('frp', 'panel'), 'Probability :', 0.5)
# ('bigram values', ('panel', 'membrane'), 'Probability :', 0.9775280898876404)
# ('bigram values', ('membrane', 'textile'), 'Probability :', 1.0)
# ('bigram values', ('textile', 'used'), 'Probability :', 1.0)
# ('bigram values', ('used', 'type'), 'Probability :', 0.3175182481751825)
# ('bigram values', ('type', 'st'), 'Probability :', 1.0)
# ('bigram values', ('st', '29,29,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('29,29,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('Intelligence', 'for'), 'Probability :', 1.0)
# ('bigram values', ('for', 'Smart'), 'Probability :', 0.23655913978494625)
# ('bigram values', ('Smart', 'Home'), 'Probability :', 0.88)
# ('bigram values', ('Home', 'Appliances,abstract'), 'Probability :', 1.0)
# ('bigram values', ('Appliances,abstract', 'main'), 'Probability :', 1.0)
# ('bigram values', ('main', 'goal'), 'Probability :', 1.0)
# ('bigram values', ('goal', 'researcher'), 'Probability :', 1.0)
# ('bigram values', ('researcher', 'designing'), 'Probability :', 0.9428571428571428)
# ('bigram values', ('designing', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('smart', 'health'), 'Probability :', 0.12290502793296089)
# ('bigram values', ('health', 'care'), 'Probability :', 0.192090395480226)
# ('bigram values', ('care', 'technology'), 'Probability :', 0.48175182481751827)
# ('bigram values', ('technology', 'develop'), 'Probability :', 0.22)
# ('bigram values', ('develop', 'strategy'), 'Probability :', 0.9428571428571428)
# ('bigram values', ('strategy', 'allowing'), 'Probability :', 1.0)
# ('bigram values', ('allowing', 'early'), 'Probability :', 1.0)
# ('bigram values', ('early', 'detection'), 'Probability :', 1.0)
# ('bigram values', ('detection', 'avoid'), 'Probability :', 0.9850746268656716)
# ('bigram values', ('avoid', 'problem'), 'Probability :', 1.0)
# ('bigram values', ('problem', 'could'), 'Probability :', 0.9565217391304348)
# ('bigram values', ('could', 'lead'), 'Probability :', 0.9850746268656716)
# ('bigram values', ('lead', 'decreased'), 'Probability :', 1.0)
# ('bigram values', ('decreased', 'independence'), 'Probability :', 1.0)
# ('bigram values', ('independence', 'medical'), 'Probability :', 1.0)
# ('bigram values', ('medical', 'analysis'), 'Probability :', 0.66)
# ('bigram values', ('analysis', 'smart'), 'Probability :', 0.9850746268656716)
# ('bigram values', ('sensor', 'intelligent'), 'Probability :', 0.1793478260869565)
# ('bigram values', ('intelligent', 'software'), 'Probability :', 0.9850746268656716)
# ('bigram values', ('software', 'agent'), 'Probability :', 1.0)
# ('bigram values', ('agent', 'distributed'), 'Probability :', 1.0)
# ('bigram values', ('distributed', 'control'), 'Probability :', 0.9850746268656716)
# ('bigram values', ('control', 'wireless'), 'Probability :', 1.0)
# ('bigram values', ('wireless', 'comm'), 'Probability :', 0.24719101123595505)
# ('bigram values', ('comm', '30,30,Smart'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('30,30,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '31,31,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('31,31,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '32,32,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('32,32,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '33,33,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('33,33,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '34,34,The'), 'Probability :', 0.01)
# ('bigram values', ('34,34,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '35,35,SMART'), 'Probability :', 0.01)
# ('bigram values', ('35,35,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '36,36,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('36,36,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '37,37,SMART'), 'Probability :', 0.01)
# ('bigram values', ('37,37,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '38,38,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('38,38,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '39,39,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('39,39,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '40,40,Smart'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('40,40,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '41,41,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('41,41,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '42,42,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('42,42,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '43,43,Experimental'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('43,43,Experimental', 'Evaluation'), 'Probability :', 1.0)
# ('bigram values', ('published', '44,44,A'), 'Probability :', 0.125)
# ('bigram values', ('44,44,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '45,45,The'), 'Probability :', 0.01)
# ('bigram values', ('45,45,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '46,46,SMART'), 'Probability :', 0.01)
# ('bigram values', ('46,46,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '47,47,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('47,47,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '48,48,SMART'), 'Probability :', 0.01)
# ('bigram values', ('48,48,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '49,49,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('49,49,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '50,50,Smart'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('50,50,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '51,51,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('51,51,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '52,52,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('52,52,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '53,53,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('53,53,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '54,54,Is'), 'Probability :', 0.01)
# ('bigram values', ('54,54,Is', 'Well-being'), 'Probability :', 1.0)
# ('bigram values', ('Well-being', 'U-Shaped'), 'Probability :', 1.0)
# ('bigram values', ('U-Shaped', 'over'), 'Probability :', 1.0)
# ('bigram values', ('over', 'the'), 'Probability :', 1.0)
# ('bigram values', ('the', 'Life'), 'Probability :', 0.125)
# ('bigram values', ('Life', 'Cycle?,present'), 'Probability :', 1.0)
# ('bigram values', ('Cycle?,present', 'evidence'), 'Probability :', 1.0)
# ('bigram values', ('evidence', 'psychological'), 'Probability :', 0.4)
# ('bigram values', ('psychological', 'wellbeing'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('wellbeing', 'ushaped'), 'Probability :', 1.0)
# ('bigram values', ('ushaped', 'life'), 'Probability :', 1.0)
# ('bigram values', ('life', 'difficulty'), 'Probability :', 0.4)
# ('bigram values', ('difficulty', 'research'), 'Probability :', 1.0)
# ('bigram values', ('research', 'issue'), 'Probability :', 0.0031446540880503146)
# ('bigram values', ('issue', 'likely'), 'Probability :', 0.2857142857142857)
# ('bigram values', ('likely', 'omitted'), 'Probability :', 1.0)
# ('bigram values', ('omitted', 'cohort'), 'Probability :', 1.0)
# ('bigram values', ('cohort', 'effect'), 'Probability :', 1.0)
# ('bigram values', ('effect', 'earlier'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('earlier', 'generation'), 'Probability :', 1.0)
# ('bigram values', ('generation', 'may'), 'Probability :', 1.0)
# ('bigram values', ('may', 'born'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('born', 'say'), 'Probability :', 1.0)
# ('bigram values', ('say', 'particularly'), 'Probability :', 1.0)
# ('bigram values', ('particularly', 'good'), 'Probability :', 0.6666666666666666)
# ('bigram values', ('good', 'bad'), 'Probability :', 0.5)
# ('bigram values', ('bad', 'time'), 'Probability :', 1.0)
# ('bigram values', ('time', 'first'), 'Probability :', 1.0)
# ('bigram values', ('first', 'using'), 'Probability :', 1.0)
# ('bigram values', ('using', 'data'), 'Probability :', 0.017857142857142856)
# ('bigram values', ('data', 'randomly'), 'Probability :', 0.4)
# ('bigram values', ('randomly', 'sampled'), 'Probability :', 1.0)
# ('bigram values', ('sampled', '55,55,The'), 'Probability :', 0.5)
# ('bigram values', ('55,55,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '56,56,SMART'), 'Probability :', 0.01)
# ('bigram values', ('56,56,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '57,57,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('57,57,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '58,58,SMART'), 'Probability :', 0.01)
# ('bigram values', ('58,58,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '59,59,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('59,59,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '60,60,Smart'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('60,60,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '61,61,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('61,61,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '62,62,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('62,62,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '63,63,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('63,63,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '64,64,The'), 'Probability :', 0.01)
# ('bigram values', ('64,64,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '65,65,SMART'), 'Probability :', 0.01)
# ('bigram values', ('65,65,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '66,66,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('66,66,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '67,67,SMART'), 'Probability :', 0.01)
# ('bigram values', ('67,67,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '68,68,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('68,68,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '69,69,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('69,69,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '70,70,The'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('70,70,The', 'strengthening'), 'Probability :', 1.0)
# ('bigram values', ('strengthening', 'the'), 'Probability :', 0.5)
# ('bigram values', ('the', 'reporting'), 'Probability :', 0.1875)
# ('bigram values', ('reporting', 'of'), 'Probability :', 0.25)
# ('bigram values', ('of', 'observational'), 'Probability :', 0.11538461538461539)
# ('bigram values', ('observational', 'studies'), 'Probability :', 0.25)
# ('bigram values', ('studies', 'in'), 'Probability :', 1.0)
# ('bigram values', ('in', 'epidemiology'), 'Probability :', 0.023076923076923078)
# ('bigram values', ('epidemiology', '(STROBE)'), 'Probability :', 0.5)
# ('bigram values', ('(STROBE)', 'statement:'), 'Probability :', 1.0)
# ('bigram values', ('statement:', 'guidelines'), 'Probability :', 1.0)
# ('bigram values', ('guidelines', 'for'), 'Probability :', 1.0)
# ('bigram values', ('for', 'reporting'), 'Probability :', 0.010752688172043012)
# ('bigram values', ('reporting', 'observational'), 'Probability :', 0.5)
# ('bigram values', ('observational', 'studies.,b'), 'Probability :', 0.25)
# ('bigram values', ('studies.,b', 'r'), 'Probability :', 1.0)
# ('bigram values', ('r', 'c'), 'Probability :', 1.0)
# ('bigram values', ('c', 'much'), 'Probability :', 1.0)
# ('bigram values', ('much', 'biomedical'), 'Probability :', 1.0)
# ('bigram values', ('biomedical', 'research'), 'Probability :', 1.0)
# ('bigram values', ('research', 'observational'), 'Probability :', 0.0047169811320754715)
# ('bigram values', ('observational', 'reporting'), 'Probability :', 0.25)
# ('bigram values', ('reporting', 'research'), 'Probability :', 0.25)
# ('bigram values', ('research', 'often'), 'Probability :', 0.0047169811320754715)
# ('bigram values', ('often', 'inadequate'), 'Probability :', 0.5)
# ('bigram values', ('inadequate', 'hamper'), 'Probability :', 1.0)
# ('bigram values', ('hamper', 'assessment'), 'Probability :', 1.0)
# ('bigram values', ('assessment', 'strength'), 'Probability :', 1.0)
# ('bigram values', ('strength', 'weakness'), 'Probability :', 1.0)
# ('bigram values', ('weakness', 'study'), 'Probability :', 1.0)
# ('bigram values', ('study', 'generalisability'), 'Probability :', 0.027522935779816515)
# ('bigram values', ('generalisability', 'strengthening'), 'Probability :', 1.0)
# ('bigram values', ('strengthening', 'reporting'), 'Probability :', 0.5)
# ('bigram values', ('observational', 'study'), 'Probability :', 0.25)
# ('bigram values', ('study', 'epidemiology'), 'Probability :', 0.027522935779816515)
# ('bigram values', ('epidemiology', 'strobe'), 'Probability :', 0.5)
# ('bigram values', ('strobe', 'initi'), 'Probability :', 1.0)
# ('bigram values', ('initi', '71,71,Smart'), 'Probability :', 0.3333333333333333)
# ('bigram values', ('71,71,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '72,72,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('72,72,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '73,73,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('73,73,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '74,74,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('74,74,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '75,75,The'), 'Probability :', 0.01)
# ...
# ('bigram values', ('899,899,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '900,900,Smart'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('900,900,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '901,901,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('901,901,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '902,902,A'), 'Probability :', 0.01)
# ('bigram values', ('902,902,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '903,903,The'), 'Probability :', 0.01)
# ('bigram values', ('903,903,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '904,904,SMART'), 'Probability :', 0.01)
# ('bigram values', ('904,904,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '905,905,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('905,905,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '906,906,SMART'), 'Probability :', 0.01)
# ('bigram values', ('906,906,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '907,907,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('907,907,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '908,908,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('908,908,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '909,909,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('909,909,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '910,910,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('910,910,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '911,911,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('911,911,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '912,912,A'), 'Probability :', 0.01)
# ('bigram values', ('912,912,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '913,913,The'), 'Probability :', 0.01)
# ('bigram values', ('913,913,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '914,914,SMART'), 'Probability :', 0.01)
# ('bigram values', ('914,914,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '915,915,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('915,915,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '916,916,SMART'), 'Probability :', 0.01)
# ('bigram values', ('916,916,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '917,917,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('917,917,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '918,918,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('918,918,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '919,919,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('919,919,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '920,920,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('920,920,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '921,921,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('921,921,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '922,922,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('922,922,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '923,923,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('923,923,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '924,924,The'), 'Probability :', 0.01)
# ('bigram values', ('924,924,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '925,925,SMART'), 'Probability :', 0.01)
# ('bigram values', ('925,925,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '926,926,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('926,926,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '927,927,SMART'), 'Probability :', 0.01)
# ('bigram values', ('927,927,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '928,928,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('928,928,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '929,929,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('929,929,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '930,930,Smart'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('930,930,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '931,931,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('931,931,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '932,932,A'), 'Probability :', 0.01)
# ('bigram values', ('932,932,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '933,933,The'), 'Probability :', 0.01)
# ('bigram values', ('933,933,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '934,934,SMART'), 'Probability :', 0.01)
# ('bigram values', ('934,934,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '935,935,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('935,935,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '936,936,SMART'), 'Probability :', 0.01)
# ('bigram values', ('936,936,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '937,937,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('937,937,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '938,938,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('938,938,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '939,939,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('939,939,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '940,940,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('940,940,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '941,941,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('941,941,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '942,942,"Whom'), 'Probability :', 0.01)
# ('bigram values', ('942,942,"Whom', 'You'), 'Probability :', 1.0)
# ('bigram values', ('inv', '943,943,A'), 'Probability :', 0.02040816326530612)
# ('bigram values', ('943,943,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '944,944,The'), 'Probability :', 0.01)
# ('bigram values', ('944,944,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '945,945,SMART'), 'Probability :', 0.01)
# ('bigram values', ('945,945,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '946,946,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('946,946,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '947,947,SMART'), 'Probability :', 0.01)
# ('bigram values', ('947,947,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '948,948,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('948,948,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '949,949,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('949,949,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '950,950,Smart'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('950,950,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '951,951,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('951,951,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '952,952,A'), 'Probability :', 0.01)
# ('bigram values', ('952,952,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '953,953,The'), 'Probability :', 0.01)
# ('bigram values', ('953,953,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '954,954,SMART'), 'Probability :', 0.01)
# ('bigram values', ('954,954,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '955,955,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('955,955,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '956,956,SMART'), 'Probability :', 0.01)
# ('bigram values', ('956,956,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '957,957,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('957,957,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '958,958,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('958,958,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '959,959,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('959,959,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '960,960,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('960,960,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '961,961,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('961,961,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '962,962,A'), 'Probability :', 0.01)
# ('bigram values', ('962,962,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '963,963,The'), 'Probability :', 0.01)
# ('bigram values', ('963,963,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '964,964,SMART'), 'Probability :', 0.01)
# ('bigram values', ('964,964,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '965,965,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('965,965,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '966,966,SMART'), 'Probability :', 0.01)
# ('bigram values', ('966,966,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '967,967,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('967,967,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '968,968,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('968,968,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '969,969,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('969,969,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '970,970,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('970,970,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '971,971,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('971,971,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '972,972,A'), 'Probability :', 0.01)
# ('bigram values', ('972,972,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '973,973,The'), 'Probability :', 0.01)
# ('bigram values', ('973,973,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '974,974,SMART'), 'Probability :', 0.01)
# ('bigram values', ('974,974,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '975,975,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('975,975,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '976,976,SMART'), 'Probability :', 0.01)
# ('bigram values', ('976,976,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '977,977,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('977,977,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '978,978,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('978,978,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '979,979,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('979,979,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '980,980,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('980,980,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '981,981,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('981,981,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '982,982,A'), 'Probability :', 0.01)
# ('bigram values', ('982,982,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '983,983,The'), 'Probability :', 0.01)
# ('bigram values', ('983,983,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '984,984,SMART'), 'Probability :', 0.01)
# ('bigram values', ('984,984,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '985,985,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('985,985,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '986,986,SMART'), 'Probability :', 0.01)
# ('bigram values', ('986,986,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '987,987,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('987,987,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '988,988,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('988,988,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '989,989,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('989,989,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)
# ('bigram values', ('delivery', '990,990,Smart'), 'Probability :', 0.02857142857142857)
# ('bigram values', ('990,990,Smart', 'Sensing'), 'Probability :', 1.0)
# ('bigram values', ('system', '991,991,Structural'), 'Probability :', 0.0015503875968992248)
# ('bigram values', ('991,991,Structural', 'health'), 'Probability :', 1.0)
# ('bigram values', ('wi', '992,992,A'), 'Probability :', 0.01)
# ('bigram values', ('992,992,A', 'Survey'), 'Probability :', 1.0)
# ('bigram values', ('biose', '993,993,The'), 'Probability :', 0.01)
# ('bigram values', ('993,993,The', 'SmartPhone'), 'Probability :', 1.0)
# ('bigram values', ('alternati', '994,994,SMART'), 'Probability :', 0.01)
# ('bigram values', ('994,994,SMART', 'SENSING'), 'Probability :', 1.0)
# ('bigram values', ('em', '995,995,AMultimodalCorpusRecordedinaHealthSmartHome,health'), 'Probability :', 0.01)
# ('bigram values', ('995,995,AMultimodalCorpusRecordedinaHealthSmartHome,health', 'smart'), 'Probability :', 1.0)
# ('bigram values', ('test', '996,996,SMART'), 'Probability :', 0.01)
# ('bigram values', ('996,996,SMART', 'TECHNOLOGIES'), 'Probability :', 1.0)
# ('bigram values', ('presc', '997,997,ADVANCED'), 'Probability :', 0.010526315789473684)
# ('bigram values', ('997,997,ADVANCED', 'COMPOSITES'), 'Probability :', 1.0)
# ('bigram values', ('st', '998,998,Distributed'), 'Probability :', 0.011494252873563218)
# ('bigram values', ('998,998,Distributed', 'Intelligence'), 'Probability :', 1.0)
# ('bigram values', ('comm', '999,999,HEALTH'), 'Probability :', 0.015151515151515152)
# ('bigram values', ('999,999,HEALTH', 'BIOMETRICS:'), 'Probability :', 1.0)

# %%
#1.3.Extract all the noun phrases and calculate the relative probabilities of each abstract
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from textblob import TextBlob
clean_data = open('clean_text.csv', "r")
_noun = lambda pos: pos[:2] == 'NN'
tokenized = nltk.word_tokenize(clean_data.read())
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if _noun(pos)] 
#all the nouns in the clean data
print(nouns)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ['Title', 'Abstract', 'Determinants', 'Credit', 'Spread', 'Changes.', 'dealer', 'transaction', 'price', 'bond', 'investigate', 'determinant', 'credit', 'spread', 'change', 'theory', 'determine', 'credit', 'spread', 'change', 'power', 'regression', 'Smart', 'Sensing', 'Technology', 'Opportunities', 'Challenges', 'sensor', 'microprocessor', 'wireless', 'communication', 'change', 'way', 'infrastructure', 'system', 'research', 'council', 'report', 'system', 'Structural', 'health', 'monitoring', 'sensors', 'excellence', 'research', 'education', 'engineering', 'area', 'laboratory', 'threestory', 'height', 'Whom', 'Matters', 'Venture', 'Capital', 'Networks', 'Investment', 'Performance', 'market', 'relationship', 'network', 'armslength', 'transaction', 'examine', 'performance', 'consequence', 'choice', 'context', 'relationship', 'vcs', 'syndicate', 'portfolio', 'company', 'A', 'Survey', 'Systems', 'Health', 'Monitoring', 'Prognosis', 'design', 'development', 'biosensor', 'system', 'health', 'monitoring', 'lot', 'attention', 'community', 'industry', 'year', 'healthcare', 'cost', 'advance', 'miniature', 'SmartPhone', 'platform', 'cameras', 'health', 'research', 'camera', 'chest', 'lanyard', 'health', 'research', 'use', 'variety', 'factor', 'smartphone', 'provide', 'alternati', 'SMART', 'SENSING', 'TECHNOLOGY', 'FOR', 'STRUCTURAL', 'HEALTH', 'MONITORING', 'sensor', 'microprocessor', 'wireless', 'communication', 'way', 'infrastructure', 'system', 'research', 'council', 'report', 'system', 'AMultimodalCorpusRecordedinaHealthSmartHome', 'health', 'home', 'nowadays', 'research', 'area', 'home', 'automation', 'support', 'people', 'loss', 'autonomy', 'evolution', 'technology', 'efficient', 'sensor', 'test', 'SMART', 'TECHNOLOGIES', 'FOR', 'STRUCTURAL', 'HEALTH', 'MONITORING', 'OF', 'AEROSPACE', 'STRUCTURES', 'paper', 'advance', 'health', 'monitoring', 'shm', 'project', 'consortium', 'research', 'innovation', 'aerospace', 'québec', 'criaq', 'project', 'technology', 'shm', 'system', 'cost', 'presc', 'Occasional', 'Paper', 'resourceconserving', 'agriculture', 'livelihood', 'metaanalysis', 'framework', 'evaluation', 'mica', 'world', 'agroforestry', 'research', 'organization', 'transformation', 'Determinants', 'Credit', 'Spread', 'Changes.', 'dealer', 'transaction', 'price', 'bond', 'investigate', 'determinant', 'credit', 'spread', 'change', 'theory', 'determine', 'credit', 'spread', 'change', 'power', 'regression', 'Stress', 'support', 'processes', 'jstor', 'notforprofit', 'service', 'help', 'researcher', 'student', 'discover', 'use', 'range', 'content', 'use', 'information', 'technology', 'tool', 'increase', 'productivity', 'form', 'scholarship', 'information', 'j', 'Smart', 'Sensing', 'Technology', 'Opportunities', 'Challenges', 'sensor', 'microprocessor', 'wireless', 'communication', 'change', 'way', 'infrastructure', 'system', 'research', 'council', 'report', 'system', 'Structural', 'health', 'monitoring', 'sensors', 'excellence', 'research', 'education', 'engineering', 'area', 'laboratory', 'threestory', 'height', 'Whom', 'Matters', 'Venture', 'Capital', 'Networks', 'Investment', 'Performance', 'market', 'relationship', 'network', 'armslength', 'transaction', 'examine', 'performance', 'consequence', 'choice', 'context', 'relationship', 'vcs', 'syndicate', 'portfolio', 'company', 'Evaluation', 'Computer', 'Science', 'Quantitative', 'Study', 'survey', 'research', 'article', 'computer', 'scientist', 'paper', 'result', 'survey', 'volume', 'refereed', 'computer', 'science', 'journal', 'conference', 'title', 'drawn', 'article', 'A', 'Survey', 'Systems', 'Health', 'Monitoring', 'Prognosis', 'design', 'development', 'biosensor', 'system', 'health', 'monitoring', 'lot', 'attention', 'community', 'industry', 'year', 'healthcare', 'cost', 'advance', 'miniature', 'Compassionate', 'mind', 'training', 'people', 'shame', 'self-criticism', 'Overview', 'pilot', 'study', 'group', 'therapy', 'approach', 'compassionate', 'mind', 'training', 'cmt', 'people', 'sel ...

# %%
df_noun = pd.DataFrame(nouns, columns = ['nouns'])
df_noun #creation of data frame
# Out:
#               nouns
# 0             Title
# 1          Abstract
# 2      Determinants
# 3            Credit
# 4            Spread
# ...             ...
# 19652   information
# 19653    management
# 19654        health
# 19655          care
# 19656      delivery
#
# [19657 rows x 1 columns]

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
clean_data = open('clean_text.csv', "r")
f = nltk.FreqDist(nouns)
f #frequncy of nouns
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# FreqDist({'A': 134,
#           'ADVANCED': 87,
#           'AEROSPACE': 95,
#           'AMultimodalCorpusRecordedinaHealthSmartHome': 99,
#           'ARRB': 1,
#           'Absence': 2,
#           'Abstract': 1,
#           'Action': 2,
#           'Adaptive': 1,
#           'Appliances': 66,
#           'BE': 34,
#           'BIOMETRICS': 34,
#           'Baby': 4,
#           'Boomer': 4,
#           'Braille': 2,
#           'CHE': 2,
#           'COMPOSITES': 87,
#           'Capacity': 2,
#           'Capital': 49,
#           'Cards': 2,
#           'Care': 4,
#           'Case': 1,
#           'Challenges': 100,
#           'Changes.': 7,
#           'Collective': 1,
#           'Compassionate': 1,
#           'Computer': 7,
#           'Conference': 1,
#           'Consumption': 1,
#           'Coping': 1,
#           'Countries': 2,
#           'Credit': 7,
#           'Cycle': 2,
#           'Definition': 1,
#           'Dependent': 1,
#           'Design': 1,
#           'Determinants': 7,
#           'Diabetes': 1,
#           'Disabled': 1,
#           'Economic': 2,
#           'Elderly': 4,
#           'Environments': 2,
#           'Evaluating': 1,
#           'Evaluation': 8,
#           'FOR': 282,
#           'Financial': 4,
#           'Foe': 1,
#           'Foundation': 1,
#           'Friend': 1,
#           'Funding': 1,
#           'GPS': 1,
#           'Gate': 1,
#           'Ghana': 1,
#           'Governance': 1,
#           'HEALTH': 229,
#           'Health': 111,
#           'Home': 72,
#           'Hostile': 2,
#           'Housing': 4,
#           'How': 1,
#           'ICUs': 1,
#           'IFS': 1,
#           'INTERNET': 34,
#           'Income': 1,
#           'India': 1,
#           'Indicators': 3,
#           'Individual': 1,
#           'Initiative': 2,
#           'Instrument': 1,
#           'Intelligence': 66,
#           'Interaction': 1,
#           'International': 3,
#           'Investment': 49,
#           'Issues': 2,
#           'Journal': 2,
#           'Language': 1,
#           'Life': 2,
#           'Literacy': 4,
#           'Location': 1,
#           'MAU/QALY': 1,
#           'MONITORING': 195,
#           'Matters': 49,
#           'Measures': 2,
#           'Medicare': 1,
#           'Mellitus': 1,
#           'Mental': 5,
#           'Mobility': 1,
#           'Model': 2,
#           'Monitoring': 104,
#           'Morocco': 1,
#           'NBER': 1,
#           'Networks': 49,
#           'No': 3,
#           'Non-Insulin': 1,
#           'OF': 95,
#           'Occasional': 1,
#           'Opportunities': 100,
#           'Optimal': 1,
#           'Options': 1,
#           'Outcome': 2,
#           'Overview': 1,
#           'PAPER': 5,
#           'Panel': 1,
#           'Paper': 11,
#           'Patient': 2,
#           'Performance': 50,
#           'Pervasive': 1,
#           'Pilot': 1,
#           'Planning': 4,
#           'Policy': 1,
#           'Posters': 1,
#           'Power': 1,
#           'Preliminary': 1,
#           'Professionals': 1,
#           'Prognosis': 100,
#           'Promotion': 2,
#           'Quantitative': 7,
#           'READY': 34,
#           'Rationale': 1,
#           'Recognizer': 2,
#           'Reforms': 1,
#           'Reminder': 2,
#           'Research': 9,
#           'Resources': 1,
#           'Results': 1,
#           'Retirement': 4,
#           'Role': 4,
#           'SENSING': 100,
#           'SMART': 316,
#           'STROBE': 3,
#           'STRUCTURAL': 195,
#           'STRUCTURES': 182,
#           'SUGI': 1,
#           'Sanitation': 1,
#           'Science': 7,
#           'Security': 4,
#           'Sensing': 100,
#           'Smart': 179,
#           'SmartPhone': 100,
#           'Social': 1,
#           'Socioeconomic': 1,
#           'Sound': 1,
#           'Spread': 7,
#           'Status': 1,
#           'Stress': 3,
#           'Struct': 1,
#           'Structural': 101,
#           'Study': 7,
#           'Survey': 102,
#           'System': 6,
#           'Systems': 100,
#           'TECHNOLOGIES': 95,
#           'TECHNOLOGY': 134,
#           'TO': 34,
#           'Tax': 1,
#           'Teacher': 2,
#           'Technology': 100,
#           'Title': 1,
#           'Toward': 1,
#           'Travel': 1,
#           'TravelSmart': 1,
#           'U-Shaped': 2,
#           'Venture': 49,
#           'Version': 2,
#           'W15/32': 1,
#           'WIDER': 1,
#           'WMH': 2,
#           'WORKING': 5,
#           'Wealth': 4,
#           'Wesleyan-CMU': 1,
#           'Whom': 49,
#           'Worker': 2,
#           'Working': 4,
#           'World': 4,
#           'ab': 2,
#           'ability': 1,
#           'abstract': 66,
#           'abstractimprovements': 1,
#           'accelerate': 1,
#           'adaptation': 1,
#           'advance': 195,
#           'aerospace': 95,
#           'age': 4,
#           'agenda': 1,
#           'agent': 66,
#           'agriculture': 1,
#           'agroforestry': 1,
#           'aid': 1,
#           'air': 1,
#           'alarm': 4,
#           'alternati': 100,
#           'analysis': 68,
#           'andor': 1,
#           'anecdotal': 1,
#           'appliance': 1,
#           'applicate': 1,
#           'application': 6,
#           'approach': 2,
#           'area': 201,
#           'armslength': 49,
#           'arrangement': 1,
#           'arrangements': 1,
#           'article': 14,
#           'assessment': 3,
#           'assistance': 2,
#           'attention': 102,
#           'auf': 1,
#           'author': 1,
#           'automation': 99,
#           'autonomy': 99,
#           'avoid': 66,
#           'b': 3,
#           'baby': 4,
#           'background': 1,
#           'bangladeshecuador': 2,
#           'bar': 87,
#           'become': 1,
#           'benefit': 1,
#           'biosensor': 100,
#           'blend': 4,
#           'body': 1,
#           'bond': 7,
#           'boomer': 4,
#           'bottleneck': 1,
#           'braill': 2,
#           'braille': 4,
#           'breadth': 1,
#           'bridge': 1,
#           'c': 3,
#           'camera': 100,
#           'cameras': 100,
#           'capacity': 1,
#           'capital': 1,
#           'car': 1,
#           'carbon': 87,
#           'card': 4,
#           'care': 137,
#           'case': 1,
#           'change': 115,
#           'character': 2,
#           'che': 2,
#           'chest': 100,
#           'chia': 1,
#           'childhood': 1,
#           'choice': 49,
#           'chpe': 5,
#           'cidi': 2,
#           'classification': 1,
#           'cmt': 1,
#           'cohort': 2,
#           'comfort': 4,
#           'comm': 66,
#           'communication': 200,
#           'community': 100,
#           'company': 49,
#           'compassionate': 1,
#           'component': 1,
#           'computati': 1,
#           'computer': 14,
#           'concern': 2,
#           'condition': 1,
#           'conference': 7,
#           'consequence': 51,
#           'conservation': 1,
#           'considers': 1,
#           'consortium': 95,
#           'constitute': 1,
#           'content': 3,
#           'context': 49,
#           'contribution': 1,
#           'control': 66,
#           'corruption': 1,
#           'cost': 195,
#           'council': 201,
#           'country': 5,
#           'cpp': 1,
#           'credit': 14,
#           'criaq': 95,
#           'cut': 1,
#           'data': 5,
#           'dealer': 7,
#           'decade': 1,
#           'delivery': 35,
#           'demand': 2,
#           'demonstrate': 1,
#           'department': 1,
#           'desc': 1,
#           'design': 103,
#           'detection': 67,
#           'determinant': 7,
#           'determination': 1,
#           'determine': 7,
#           'development': 104,
#           'device': 3,
#           'die': 2,
#           'dif': 1,
#           'difficulty': 2,
#           'disabilities': 1,
#           'disability': 1,
#           'discover': 3,
#           'discussion': 3,
#           'disease': 1,
#           'disseminate': 1,
#           'dissemination': 1,
#           'doctor': 1,
#           'document': 2,
#           'dokumente': 2,
#           'door': 1,
#           'dot': 2,
#           'dp': 1,
#           'drawn': 7,
#           'dürfen': 2,
#           'economist': 1,
#           'econstor': 1,
#           'education': 102,
#           'effect': 3,
#           'efficient': 99,
#           'eigenen': 1,
#           'elasticity': 1,
#           'emission': 2,
#           'energy': 2,
#           'engineering': 100,
#           'entrance': 1,
#           'enumerator': 2,
#           'environment': 5,
#           'epidemiology': 6,
#           'esrc': 1,
#           'evaluation': 10,
#           'evidence': 5,
#           'evidence.': 1,
#           'evolution': 99,
#           'examine': 49,
#           'examines': 1,
#           'excellence': 100,
#           'expectancy': 1,
#           'explanation': 1,
#           'facilities1': 2,
#           'factor': 102,
#           'family': 1,
#           'fibre': 87,
#           'finance': 4,
#           'finding': 1,
#           'finger': 2,
#           'focus': 5,
#           'form': 3,
#           'foundation': 1,
#           'framework': 1,
#           'frp': 87,
#           'ft': 1,
#           'future': 1,
#           'für': 1,
#           'gap': 1,
#           'gas': 1,
#           'gate': 1,
#           'generalisability': 3,
#           'generate': 1,
#           'generation': 2,
#           'gespeichert': 1,
#           'glass': 87,
#           'globe': 4,
#           'goal': 66,
#           'goodman': 1,
#           'governance': 1,
#           'government': 1,
#           'greenhouse': 1,
#           'grid': 1,
#           'group': 1,
#           'growth': 2,
#           'guidelines': 3,
#           'ha': 1,
#           'health': 842,
#           'healthcare': 100,
#           'height': 100,
#           'help': 3,
#           'home': 213,
#           'homes': 1,
#           'hospital': 1,
#           'house': 2,
#           'household': 4,
#           'ifs': 1,
#           'impact': 1,
#           'imperfection': 4,
#           'income': 2,
#           'increase': 3,
#           'independence': 66,
#           'india': 2,
#           'indonesia': 2,
#           'industry': 100,
#           'inequality': 2,
#           'informatics': 69,
#           'information': 76,
#           'infrastructure': 201,
#           'initi': 3,
#           'initiative': 1,
#           'innovation': 95,
#           'instance': 4,
#           'institution': 1,
#           'instrument': 3,
#           'intelligence': 2,
#           'intelligent': 66,
#           'interaction': 1,
#           'interest': 34,
#           'interpretation': 1,
#           'intervention': 2,
#           'interview': 2,
#           'investigate': 7,
#           'issue': 7,
#           'j': 3,
#           'joshua': 1,
#           'journal': 7,
#           'jstor': 3,
#           'knowledge': 2,
#           'kommerzielle': 1,
#           'l': 4,
#           'laboratory': 100,
#           'language': 1,
#           'lanyard': 100,
#           'learning': 2,
#           'life': 5,
#           'literature': 1,
#           'livelihood': 1,
#           'load': 1,
#           'location': 2,
#           'look': 1,
#           'loss': 100,
#           'lot': 100,
#           'lowcost': 1,
#           'machine': 2,
#           'majority': 1,
#           'management': 36,
#           'market': 49,
#           'material': 88,
#           'mean': 1,
#           'measure': 1,
#           'meet': 1,
#           'membrane': 87,
#           'message': 1,
#           'metaanalysis': 1,
#           'method': 3,
#           'methodology': 5,
#           'mica': 1,
#           'microprocessor': 200,
#           'migration': 1,
#           'mind': 2,
#           'miniature': 100,
#           'mobility': 2,
#           'model': 8,
#           'monitor': 1,
#           'monitoring': 302,
#           'morocco': 1,
#           'mortality': 1,
#           'movement': 1,
#           'multicomponent': 1,
#           'network': 50,
#           'nh': 1,
#           'notforprofit': 3,
#           'nowadays': 99,
#           'number': 11,
#           'oder': 1,
#           'offer': 3,
#           'onboard': 1,
#           'operation': 1,
#           'optimise': 34,
#           'option': 1,
#           'order': 1,
#           'organisation': 5,
#           'organization': 3,
#           'others': 4,
#           'overview': 3,
#           'panel': 89,
#           'paper': 131,
#           'people': 114,
#           'perception': 1,
#           'performance': 49,
#           'person': 3,
#           'persons': 2,
#           'perspectives': 1,
#           'peru': 2,
#           'pilot': 2,
#           'platform': 100,
#           'play': 1,
#           'pointofsale': 2,
#           'policy': 9,
#           'population': 2,
#           'portfolio': 49,
#           'post': 1,
#           'poverty': 2,
#           'power': 9,
#           'predic': 1,
#           'predict': 1,
#           'presc': 95,
#           'presentation': 1,
#           'price': 7,
#           'problem': 69,
#           'process': 1,
#           'processes': 3,
#           'productivity': 4,
#           'program': 10,
#           'project': 191,
#           'promote': 4,
#           'prototype': 1,
#           'provide': 100,
#           'public': 3,
#           'purpose': 1,
#           'quality': 1,
#           'question': 4,
#           'québec': 95,
#           'r': 3,
#           'range': 4,
#           'recognition': 2,
#           'reduction': 1,
#           'refereed': 7,
#           'refers': 34,
#           'reform': 2,
#           'regression': 7,
#           'relationship': 100,
#           'reminder': 1,
#           'remit': 1,
#           'report': 204,
#           'reporting': 6,
#           'require': 1,
#           'research': 737,
#           'researcher': 70,
#           'resident': 2,
#           'resource': 1,
#           'resourceconserving': 1,
#           'respect': 1,
#           'response': 1,
#           'result': 9,
#           'retirement': 4,
#           'revenue': 1,
#           'review': 4,
#           'risk': 1,
#           'role': 3,
#           'sa': 1,
#           'safety': 1,
#           'salient': 1,
#           'sample': 2,
#           'scholarship': 3,
#           'school': 2,
#           'science': 9,
#           'scientist': 7,
#           'scope': 1,
#           'sector': 2,
#           'security': 8,
#           'see': 1,
#           'self-criticism': 1,
#           'selfacceptance': 1,
#           'selfcriticism': 2,
#           'sensor': 368,
#           'sensors': 100,
#           'service': 6,
#           'shame': 2,
#           'shm': 190,
#           'show': 4,
#           'side': 2,
#           'sie': 1,
#           'smart': 68,
#           'smartphone': 100,
#           'society': 1,
#           'software': 66,
#           'solution': 2,
#           'spec': 1,
#           'speech': 1,
#           'speed': 1,
#           'spread': 14,
#           'st': 87,
#           'standardnutzungsbedingungen': 1,
#           'statement': 3,
#           'steel': 87,
#           'strand': 87,
#           'strategy': 66,
#           'strength': 3,
#           'stress': 1,
#           'strobe': 3,
#           'structure': 175,
#           'student': 3,
#           'studies': 3,
#           'studies.': 3,
#           'study': 10,
#           'suggest': 1,
#           'support': 105,
#           'survey': 18,
#           'syndicate': 49,
#           'syndrome': 1,
#           'synthesis.': 1,
#           'system': 645,
#           'systems': 1,
#           'target': 1,
#           'tax': 1,
#           'technology': 301,
#           'tendon': 87,
#           'term': 34,
#           'terminal': 2,
#           'test': 100,
#           'textile': 87,
#           'thank': 1,
#           'theory': 7,
#           'therapy': 1,
#           'thing': 3,
#           'threestory': 100,
#           'time': 2,
#           'title': 7,
#           'tool': 3,
#           'touch': 2,
#           'towards': 1,
#           'training': 2,
#           'transaction': 56,
#           'transformation': 1,
#           'travel': 1,
#           'travelsmart': 2,
#           'trend': 1,
#           'trust': 2,
#           'type': 87,
#           'uganda': 2,
#           'und': 1,
#           'unit': 1,
#           'use': 107,
#           'user': 1,
#           'variable': 1,
#           'variety': 100,
#           'vcs': 49,
#           'ventilation': 1,
#           'version': 2,
#           'vervielfältigen': 1,
#           'visit': 2,
#           'volume': 7,
#           'way': 203,
#           'weakness': 3,
#           'wealth': 4,
#           'wellbeing': 2,
#           'wire': 87,
#           'wireless': 266,
#           'wissenschaftlichen': 1,
#           'wmh': 2,
#           'woman': 1,
#           'word': 2,
#           'work': 3,
#           'worker': 2,
#           'world': 8,
#           'worldwide': 1,
#           'wssns': 2,
#           'year': 103,
#           'yeefei': 1,
#           'zu': 1,
#           'zugänglich': 1,
#           'zum': 1,
#           'zwecke': 1,
#           'zwecken': 1,
#           'öffentlich': 2,
#           'öffentliche': 1,
#           '”': 3})

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
#2.1.To build the documents-terms weights (tf*idf) matrix bold text.
#calculating tf 
tf_result = (df['Abstract']).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf_result.columns = ['Abstract','tf']
tf_result
# Out:
#          Abstract     tf
# 0          change  215.0
# 1          credit   14.0
# 2          spread   14.0
# 3           quote    7.0
# 4     explanatory    7.0
# ..            ...    ...
# 823       predict    1.0
# 824      deriving    1.0
# 825     applicate    1.0
# 826      approach    1.0
# 827  abstractthis    1.0
#
# [828 rows x 2 columns]

# %%
import numpy as np
#calculating tf*idf
for i,j in enumerate(tf_result['Abstract']):
  tf_result.loc[i, 'idf'] = np.log(df.shape[0]/(len(df[df['Abstract'].str.contains(j)])))
tf_result['tf*idf'] = tf_result['tf'] * tf_result['idf']
tf_result #shows tf.idf values
# Out:
#          Abstract     tf       idf      tf*idf
# 0          change  215.0  1.570217  337.596698
# 1          credit   14.0  4.961845   69.465832
# 2          spread   14.0  2.234926   31.288970
# 3           quote    7.0  4.961845   34.732916
# 4     explanatory    7.0  4.961845   34.732916
# ..            ...    ...       ...         ...
# 823       predict    1.0  6.907755    6.907755
# 824      deriving    1.0  6.907755    6.907755
# 825     applicate    1.0  6.907755    6.907755
# 826      approach    1.0  6.907755    6.907755
# 827  abstractthis    1.0  6.907755    6.907755
#
# [828 rows x 4 columns]

# %%
#2.2.Rank the documents with respect to query by using cosine similarity.
#importing libraries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
import numpy.linalg as LA

# %%
tn_set = df['Abstract'].values.tolist() 
tt_set = "abstract smart sensor embedded microprocessor wireless communication link potential change fundamentally way civil infrastructure system monitored controlled maintained indeed national research council report noted use networked system" 
tt_set = [tt_set]
stopWords = stopwords.words('english')
vzer = CountVectorizer(stop_words = stopWords)
transformer = TfidfTransformer()
print(transformer)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
tnVectorizerArray = vzer.fit_transform(tn_set).toarray()
ttVectorizerArray = vzer.transform(tt_set).toarray()
cx = lambda a, b : np.inner(a, b)/(LA.norm(a)*LA.norm(b))
cosine_values = []
for vector in tnVectorizerArray:
        for testV in ttVectorizerArray:
            cosine = cx(vector, testV)
            cosine_values.append(cosine)
df_result = df.filter(['Abstract'], axis=1)
se = pd.Series(cosine_values)
df_result['Cosine_similarity'] = se.values
df_result
# Out:
#                                               Abstract  Cosine_similarity
# 0    abstract using dealer quote transaction price ...           0.098480
# 1    abstract smart sensor embedded microprocessor ...           1.000000
# 2    excellence research education contributed grea...           0.079181
# 3    abstract many financial market characterized s...           0.035737
# 4    abstractthe design development wearable biosen...           0.071474
# ..                                                 ...                ...
# 995  health smart home nowadays explored research a...           0.096976
# 996  paper present recent advance structural health...           0.096976
# 997  summary many advanced composite material propo...           0.030528
# 998  abstract main goal researcher designing smart ...           0.161627
# 999  health informatics increasingly interest due p...           0.083045
#
# [1000 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each of the 500 review (if you collected the data from citeseer, you can think of other text classfication tasks instead of sentiment analysis) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link: https://github.com/vaishnavivyasam/Vaishnavi_INFO5731_Fall2021/blob/main/sentimentanalysis.csv
